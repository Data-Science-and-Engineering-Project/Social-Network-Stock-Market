# %% [markdown]
# ## The Problem

# %%
import pandas as pd
import psycopg2

# Load all records from holdings_new where quarter_end = '2025-06-30'
query_all_holdings = """
SELECT *
FROM holdings_new
WHERE quarter_end = '2025-06-30'
"""

conn = psycopg2.connect(
    dbname="Social_13F",
    user="postgres",
    password="Test123",
    host="127.0.0.1",
    port=5432
)

df_holdings_jun2025 = pd.read_sql_query(query_all_holdings, conn)
conn.close()

df_holdings_jun2025.drop(columns=['accessionnumber','infotablesk'], inplace=True)

# Convert all string columns in the dataframe to lowercase
# Convert only columns that are string/object dtype to string first, then lowercase safely
for col in df_holdings_jun2025.select_dtypes(include="object").columns:
    df_holdings_jun2025[col] = df_holdings_jun2025[col].astype(str).str.lower()

df_holdings_jun2025.head()
# Out:
# C:\Users\potda\AppData\Local\Temp\ipykernel_25424\2736075059.py:19: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_holdings_jun2025 = pd.read_sql_query(query_all_holdings, conn)
#                    nameofissuer      cusip    value  sshprnamt  filingdate  \
# 0                         3m co  88579y101   7308.0       48.0  2025-08-29
# 1                   abbott labs  002824100  90855.0      668.0  2025-08-29
# 2                    abbvie inc  00287y109  25987.0      140.0  2025-08-29
# 3  abrdn healthcare opportuniti  879105104  14822.0      806.0  2025-08-29
# 4                    adient plc  g0084w101     39.0        2.0  2025-08-29
#
#           cik quarter_end  value_per_share
# 0  0002010029  2025-06-30       152.240000
# 1  0002010029  2025-06-30       136.009999
# 2  0002010029  2025-06-30       185.620000
# 3  0002010029  2025-06-30        18.390000
# 4  0002010029  2025-06-30        19.460000

# %%
df_holdings_jun2025.shape
# Out:
# (2989722, 8)

# %% [markdown]
# number of unique cusip in Q2_2025

# %%
len(df_holdings_jun2025['cusip'].unique())
# Out:
# 22244

# %% [markdown]
# lets see how much (nameofissuer,cusip) does APPLE have

# %%
query_apple = """
SELECT cusip,nameofissuer, COUNT(*) as record_count
FROM holdings_new
WHERE nameofissuer LIKE '%APPLE%'
AND quarter_end = '2025-06-30'
GROUP BY cusip,nameofissuer
ORDER BY COUNT(*) DESC;
"""

df_apple = pd.read_sql_query(query_apple, psycopg2.connect(
    dbname="Social_13F",
    user="postgres",
    password="Test123",
    host="127.0.0.1",
    port=5432
))
df_apple
# Out:
# C:\Users\potda\AppData\Local\Temp\ipykernel_25424\1228503417.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_apple = pd.read_sql_query(query_apple, psycopg2.connect(
#         cusip                                  nameofissuer  record_count
# 0   037833100                                     APPLE INC          7210
# 1   03784Y200                    APPLE HOSPITALITY REIT INC           419
# 2   037833100                                 APPLE INC COM           342
# 3   037833100                                         APPLE            76
# 4   577345101                       MAUI LD & PINEAPPLE INC            70
# ..        ...                                           ...           ...
# 63  577345101                     MAUI LD&PINEAPPLE INC COM             1
# 64  65370G109                            NICHOLAS APPLEGATE             1
# 65  71377A103                    APPLE HOSPITALITY REIT INC             1
# 66  78433H725  KURV YIELD PREMIUM STRATEGY APPLE (AAPL) ETF             1
# 67  922908363                                     APPLE INC             1
#
# [68 rows x 3 columns]

# %% [markdown]
# lets see decsending unique(cusip) by groupby

# %%
query_apple = """
SELECT cusip, COUNT(*) as record_count
FROM holdings_new
WHERE nameofissuer LIKE '%APPLE%'
AND quarter_end = '2025-06-30'
GROUP BY cusip
ORDER BY COUNT(*) DESC;
"""

df_apple = pd.read_sql_query(query_apple, psycopg2.connect(
    dbname="Social_13F",
    user="postgres",
    password="Test123",
    host="127.0.0.1",
    port=5432
))
df_apple
# Out:
# C:\Users\potda\AppData\Local\Temp\ipykernel_25424\599844435.py:10: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   df_apple = pd.read_sql_query(query_apple, psycopg2.connect(
#         cusip  record_count
# 0   037833100          7766
# 1   03784Y200           474
# 2   577345101            93
# 3   037833950             4
# 4   72303K207             4
# 5   037833900             3
# 6   H50430232             1
# 7   037833BY5             1
# 8   65370G109             1
# 9   71377A103             1
# 10  78433H725             1
# 11  922908363             1

# %% [markdown]
# ## Import the russell3000 index and find for each ticker his unique cusip

# %% [markdown]
# load the russell3000 index symbols from the file and produce 3word by name

# %%
import pandas as pd

# Load the CSV
russell3000_df = pd.read_csv("..\Data\Indexes\Holdings_details_Russell_3000_ETF.csv", header=None, names=['HOLDINGS', 'TICKER', 'SECTOR'])

# Remove the first row if it's a repeated header (shouldn't appear in final DataFrame)
if (russell3000_df.iloc[0] == ['holdings', 'ticker', 'sector']).all():
    russell3000_df = russell3000_df.iloc[1:].reset_index(drop=True)

# Lowercase the entire DataFrame (string columns only)
russell3000_df = russell3000_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)

# Function to get first 3 words from the HOLDINGS column
def first_three_words(name):
    words = str(name).split()
    return " ".join(words[:3])

# Add new column with first 3 words from the HOLDINGS column
russell3000_df["HOLDINGS_3WORDS"] = russell3000_df["HOLDINGS"].apply(first_three_words)

# Remove again any potential accidental row where HOLDINGS_3WORDS == 'holdings', to ensure header isn't present
russell3000_df = russell3000_df[russell3000_df["HOLDINGS_3WORDS"] != "holdings"].reset_index(drop=True)

# Display (optional)
russell3000_df
# Out:
# C:\Users\potda\AppData\Local\Temp\ipykernel_25424\1364010025.py:11: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   russell3000_df = russell3000_df.applymap(lambda x: x.lower() if isinstance(x, str) else x)
#                       HOLDINGS TICKER  \
# 0                  nvidia corp   nvda
# 1                    apple inc   aapl
# 2               microsoft corp   msft
# 3               amazon.com inc   amzn
# 4                 broadcom inc   avgo
# ...                        ...    ...
# 2945              gohealth inc   goco
# 2946  gemini space station inc   gemi
# 2947    third harmonic bio inc   thrd
# 2948      gci liberty inc-cl a  gliba
# 2949   sterling bancorp inc/mi    sbt
#
#                                           SECTOR          HOLDINGS_3WORDS
# 0                                 semiconductors              nvidia corp
# 1     technology hardware, storage & peripherals                apple inc
# 2                               systems software           microsoft corp
# 3                               broadline retail           amazon.com inc
# 4                                 semiconductors             broadcom inc
# ...                                          ...                      ...
# 2945                           insurance brokers             gohealth inc
# 2946                  financial exchanges & data     gemini space station
# 2947                             pharmaceuticals       third harmonic bio
# 2948       integrated telecommunication services       gci liberty inc-cl
# 2949                              regional banks  sterling bancorp inc/mi
#
# [2950 rows x 4 columns]

# %% [markdown]
# find cusip to ticker by the most frequent cusip for 3-->words

# %%
# 1. Pre-filter the relevant quarter once to avoid repeated filtering inside the loop
holdings_q = df_holdings_jun2025[df_holdings_jun2025['quarter_end'] == "2025-06-30"].copy()

# 2. Optimization Stage: Map unique issuers to their most frequent CUSIP
# This drastically reduces the search space from millions of records to a few thousand unique names.
issuer_to_top_cusip = (
    holdings_q.groupby(['nameofissuer', 'cusip'])
    .size()
    .reset_index(name='count')
    .sort_values(['nameofissuer', 'count'], ascending=[True, False])
    .drop_duplicates('nameofissuer')
)

# Store unique issuer names and their top CUSIPs in arrays for faster iteration
unique_issuers = issuer_to_top_cusip['nameofissuer'].values
top_cusips = issuer_to_top_cusip['cusip'].values

cusip_results = []

# 3. Main Matching Loop
# Instead of searching the full DataFrame, we search only within the unique issuer list
for idx, row in russell3000_df.iterrows():
    threewords = row['HOLDINGS_3WORDS']
    
    # 1. Create a boolean mask for all unique issuers that contain the 3 words
    mask = [threewords in issuer for issuer in unique_issuers]
    
    if any(mask):
        # 2. Get all matching rows from our aggregated table
        # Since 'mask' corresponds to the rows in 'issuer_to_top_cusip'
        matches = issuer_to_top_cusip[mask]
        
        # 3. Find the row with the maximum global count among these matches
        # This mirrors the 'ORDER BY count(*) DESC LIMIT 1' logic from your SQL
        best_row_index = matches['count'].idxmax()
        best_cusip = matches.loc[best_row_index, 'cusip']
        
        cusip_results.append(best_cusip)
    else:
        cusip_results.append(None)

# 4. Update the original DataFrame with the optimized results
russell3000_df["CUSIP"] = cusip_results

# %% [markdown]
# check this method by SPY banchmark to estimate the accuracy of the system

# %%
import pandas as pd

def load_and_lowercase_spy(filepath):
    """Load SPY CSV and lowercase all string columns."""
    spy_df = pd.read_csv(filepath)
    for col in spy_df.columns:
        if spy_df[col].dtype == 'O':
            spy_df[col] = spy_df[col].str.lower()
    return spy_df

def lowercase_df_columns(df):
    """Return a copy of df with all string columns lowercased."""
    new_df = df.copy()
    for col in new_df.columns:
        if new_df[col].dtype == 'O':
            new_df[col] = new_df[col].str.lower()
    return new_df

def merge_by_ticker(russell3000_df, spy_df):
    """Merge russell3000 and SPY dataframes on ticker columns."""
    merged = pd.merge(
        russell3000_df,
        spy_df,
        left_on='TICKER',
        right_on='Ticker',
        suffixes=('', '_SPY'),
        how='outer',
        indicator=True
    )
    return merged

def build_comparison_df(merged_df):
    """Create a DataFrame comparing found vs. ground-truth CUSIPs."""
    # Use appropriate column for truth
    if 'CUSIP_SPY' in merged_df.columns:
        cusip_truth = merged_df['CUSIP_SPY']
    else:
        cusip_truth = merged_df['CUSIP']
    result_compare = pd.DataFrame({
        'TICKER': merged_df['TICKER'].combine_first(merged_df['Ticker']),
        'cusip_found': merged_df['CUSIP'],
        'cusip_truth': cusip_truth,
        'source': merged_df['_merge']
    })
    result_compare['is_match'] = result_compare['cusip_found'] == result_compare['cusip_truth']
    return result_compare

def cusip_match_stats(compare_df, verbose=True):
    """Print match stats and show matched/unmatched DataFrames."""
    matched = compare_df[compare_df['source'] == 'both']
    num_matches = matched['is_match'].sum()
    total_compared = len(matched)
    percent_matches = (num_matches / total_compared) * 100 if total_compared else 0

    if verbose:
        print(f"Matched CUSIPs: {num_matches} / {total_compared} ({percent_matches:.2f}%)")

    matched_df = matched[matched['is_match']]
    unmatched_df = matched[~matched['is_match']]
    if verbose:
        print("First matches:")
        print(matched_df.head())
        print("\nFirst non-matches:")
        print(unmatched_df.head())
    return matched_df, unmatched_df, percent_matches

# ==== PIPELINE ====
# 1. Load and clean SPY dataframe
spy_df = load_and_lowercase_spy("../Data/Indexes/SPY.csv")

# 2. Lowercase all columns of russell3000 (copy)
russell3000_lower = lowercase_df_columns(russell3000_df)

# 3. Merge on TICKER
merged = merge_by_ticker(russell3000_lower, spy_df)

# 4. Build comparison table
result_compare = build_comparison_df(merged)

# 5. Analyze matches and print results
matched_df, unmatched_df, percent_matches = cusip_match_stats(result_compare, verbose=True)
# Out:
# Matched CUSIPs: 490 / 496 (98.79%)
# First matches:
#    TICKER cusip_found cusip_truth source  is_match
# 1       a   00846u101   00846u101   both      True
# 8    aapl   037833100   037833100   both      True
# 12   abbv   00287y109   00287y109   both      True
# 18   abnb   009066101   009066101   both      True
# 21    abt   002824100   002824100   both      True
#
# First non-matches:
#      TICKER cusip_found cusip_truth source  is_match
# 652     cpb        None   134429109   both     False
# 1067    fox   35137l105   35137l204   both     False
# 1185   goog   02079k305   02079k107   both     False
# 1923    nws   65249b109   65249b208   both     False
# 2188      q        None   74743l100   both     False

# %%
tickersunmatched = unmatched_df['TICKER'].tolist()
russell3000_df[russell3000_df['TICKER'].isin(tickersunmatched)]
# Out:
#                     HOLDINGS TICKER                               SECTOR  \
# 6               alphabet inc   goog         interactive media & services
# 195                  slb ltd    slb       oil & gas equipment & services
# 463    qnity electronics inc      q  semiconductor materials & equipment
# 703                 fox corp    fox                         broadcasting
# 861   campbell's company/the    cpb               packaged foods & meats
# 1583               news corp    nws                           publishing
#
#              HOLDINGS_3WORDS      CUSIP
# 6               alphabet inc  02079k305
# 195                  slb ltd       None
# 463    qnity electronics inc       None
# 703                 fox corp  35137l105
# 861   campbell's company/the       None
# 1583               news corp  65249b109

# %%
russell3000_df.drop(
    russell3000_df[russell3000_df['CUSIP'].isna() | (russell3000_df['CUSIP'].str.strip() == '')].index,
    inplace=True
)

# %%
# Get a list of unique CUSIP values left in russell3000_df
cusip_list = russell3000_df['CUSIP'].unique().tolist()

# Filter df_holdings_jun2025 to keep only records where the 'cusip' is in cusip_list
before_holdings = len(df_holdings_jun2025)
c_before, r_before = df_holdings_jun2025['cusip'].nunique(), len(df_holdings_jun2025)

df_holdings_jun2025 = df_holdings_jun2025[df_holdings_jun2025['cusip'].isin(cusip_list)]
after_holdings = len(df_holdings_jun2025)

print(f"Rows remaining in df_holdings_jun2025 after filtering: {after_holdings}")
print(f"Rows dropped from df_holdings_jun2025: {before_holdings - after_holdings}")


# filtering already done above
c_after, r_after = df_holdings_jun2025['cusip'].nunique(), len(df_holdings_jun2025)
print(f"CUSIP before: {c_before}, after: {c_after} (diff: {c_before-c_after}, {100*(c_before-c_after)/c_before:.2f}%)")
print(f"Rows before: {r_before}, after: {r_after} (diff: {r_before-r_after}, {100*(r_before-r_after)/r_before:.2f}%)")
# Out:
# Rows remaining in df_holdings_jun2025 after filtering: 1966154
# Rows dropped from df_holdings_jun2025: 1023568
# CUSIP before: 22244, after: 2866 (diff: 19378, 87.12%)
# Rows before: 2989722, after: 1966154 (diff: 1023568, 34.24%)

# %% [markdown]
# ## load Index Tickers --> CUSIP

# %% [markdown]
# ## get historyprices for thr tickers for all qaurters

# %%
EDOHD_API="key in env"

# %%
import psycopg2

# Connect to the database (update with your credentials as needed)
conn = psycopg2.connect(
    dbname="Social_13F",
    user="postgres",
    password="Test123",
    host="127.0.0.1",
    port="5432"
)

# Query all unique dates from quarter_end column in holdings_new table
query_unique_quarters = "SELECT DISTINCT quarter_end FROM holdings_new ORDER BY quarter_end;"

with conn.cursor() as cur:
    cur.execute(query_unique_quarters)
    # Save the unique dates to a list
    unique_quarter_dates = [row[0] for row in cur.fetchall()]

print(unique_quarter_dates)
conn.close()
# Out:
# [datetime.date(2013, 6, 30), datetime.date(2013, 9, 30), datetime.date(2013, 12, 31), datetime.date(2014, 3, 31), datetime.date(2014, 6, 30), datetime.date(2014, 9, 30), datetime.date(2014, 12, 31), datetime.date(2015, 3, 31), datetime.date(2015, 6, 30), datetime.date(2015, 9, 30), datetime.date(2015, 12, 31), datetime.date(2016, 3, 31), datetime.date(2016, 6, 30), datetime.date(2016, 9, 30), datetime.date(2016, 12, 31), datetime.date(2017, 3, 31), datetime.date(2017, 6, 30), datetime.date(2017, 9, 30), datetime.date(2017, 12, 31), datetime.date(2018, 3, 31), datetime.date(2018, 6, 30), datetime.date(2018, 9, 30), datetime.date(2018, 12, 31), datetime.date(2019, 3, 31), datetime.date(2019, 6, 30), datetime.date(2019, 9, 30), datetime.date(2019, 12, 31), datetime.date(2020, 3, 31), datetime.date(2020, 6, 30), datetime.date(2020, 9, 30), datetime.date(2020, 12, 31), datetime.date(2021, 3, 31), datetime.date(2021, 6, 30), datetime.date(2021, 9, 30), datetime.date(2021, 12, 31), datetime.date(2022, 3, 31), datetime.date(2022, 6, 30), datetime.date(2022, 9, 30), datetime.date(2022, 12, 31), datetime.date(2023, 3, 31), datetime.date(2023, 6, 30), datetime.date(2023, 9, 30), datetime.date(2023, 12, 31), datetime.date(2024, 3, 31), datetime.date(2024, 6, 30), datetime.date(2024, 9, 30), datetime.date(2024, 12, 31), datetime.date(2025, 3, 31), datetime.date(2025, 6, 30)]

# %%
pip install pandas_market_calendars --quiet
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
test_dates = unique_quarter_dates.tolist() if hasattr(unique_quarter_dates, 'tolist') else list(unique_quarter_dates)
# Convert dates to string format 'YYYY-MM-DD' for API compatibility
test_dates = [d.strftime('%Y-%m-%d') if hasattr(d, 'strftime') else str(d) for d in test_dates]

# %%
import pandas_market_calendars as mcal
import pandas as pd

# Convert test_dates to pandas Timestamp
test_dates_pd = [pd.Timestamp(d) for d in test_dates]

# Get NYSE trading calendar
nyse = mcal.get_calendar('NYSE')

# Determine the date range needed from test_dates
min_date = min(test_dates_pd)
max_date = max(test_dates_pd)

# Query trading days for the range of dates in test_dates
calendar_schedule = nyse.schedule(start_date=min_date, end_date=max_date)
trading_days = set(calendar_schedule.index)

# For each date, if not trading day, move to next valid trading day
adjusted_dates = []
for date in test_dates_pd:
    if date in trading_days:
        adjusted_dates.append(date)
        print(f"{date.strftime('%Y-%m-%d')} is a trading day: True")
    else:
        # Find next trading day after this date
        future_trading_days = [d for d in trading_days if d > date]
        if future_trading_days:
            next_trading_day = min(future_trading_days)
            adjusted_dates.append(next_trading_day)
            print(f"{date.strftime('%Y-%m-%d')} is not a trading day. Set to: {next_trading_day.strftime('%Y-%m-%d')}")
        else:
            adjusted_dates.append(date)
            print(f"{date.strftime('%Y-%m-%d')} is not a trading day, and no future trading day found.")

# Update test_dates to be the adjusted trading days list in string format
test_dates = [d.strftime('%Y-%m-%d') for d in adjusted_dates]
# Out:
# 2013-06-30 is not a trading day. Set to: 2013-07-01
# 2013-09-30 is a trading day: True
# 2013-12-31 is a trading day: True
# 2014-03-31 is a trading day: True
# 2014-06-30 is a trading day: True
# 2014-09-30 is a trading day: True
# 2014-12-31 is a trading day: True
# 2015-03-31 is a trading day: True
# 2015-06-30 is a trading day: True
# 2015-09-30 is a trading day: True
# 2015-12-31 is a trading day: True
# 2016-03-31 is a trading day: True
# 2016-06-30 is a trading day: True
# 2016-09-30 is a trading day: True
# 2016-12-31 is not a trading day. Set to: 2017-01-03
# 2017-03-31 is a trading day: True
# 2017-06-30 is a trading day: True
# 2017-09-30 is not a trading day. Set to: 2017-10-02
# 2017-12-31 is not a trading day. Set to: 2018-01-02
# 2018-03-31 is not a trading day. Set to: 2018-04-02
# 2018-06-30 is not a trading day. Set to: 2018-07-02
# 2018-09-30 is not a trading day. Set to: 2018-10-01
# 2018-12-31 is a trading day: True
# 2019-03-31 is not a trading day. Set to: 2019-04-01
# 2019-06-30 is not a trading day. Set to: 2019-07-01
# 2019-09-30 is a trading day: True
# 2019-12-31 is a trading day: True
# 2020-03-31 is a trading day: True
# 2020-06-30 is a trading day: True
# 2020-09-30 is a trading day: True
# 2020-12-31 is a trading day: True
# 2021-03-31 is a trading day: True
# 2021-06-30 is a trading day: True
# 2021-09-30 is a trading day: True
# 2021-12-31 is a trading day: True
# 2022-03-31 is a trading day: True
# 2022-06-30 is a trading day: True
# 2022-09-30 is a trading day: True
# 2022-12-31 is not a trading day. Set to: 2023-01-03
# 2023-03-31 is a trading day: True
# 2023-06-30 is a trading day: True
# 2023-09-30 is not a trading day. Set to: 2023-10-02
# 2023-12-31 is not a trading day. Set to: 2024-01-02
# 2024-03-31 is not a trading day. Set to: 2024-04-01
# 2024-06-30 is not a trading day. Set to: 2024-07-01
# 2024-09-30 is a trading day: True
# 2024-12-31 is a trading day: True
# 2025-03-31 is a trading day: True
# 2025-06-30 is a trading day: True

# %%
import requests
import time
# Helper function to fetch adjusted close price for a single ticker on a single date from EODHD API
def fetch_adjusted_close(ticker, date, api_key, session=None, max_retries=3):
    """
    Fetch adjusted close price for given ticker and date using EODHD API.

    Parameters:
        ticker (str): The stock ticker.
        date (str): Date in 'YYYY-MM-DD' format.
        api_key (str): EODHD API key.
        session (requests.Session): An optional requests session.
        max_retries (int): Max retries for network errors.

    Returns:
        float or None: Adjusted close price, or None if not found.
    """
    # For Russell 3000, most are US stocks on "US" exchange
    url = f"https://eodhd.com/api/eod/{ticker}.US"
    params = {
        'api_token': api_key,
        'from': date,
        'to': date,
        'period': 'd',
        'fmt': 'json',
        'adjusted': 1,
    }
    session = session or requests.Session()
    for attempt in range(max_retries):
        try:
            response = session.get(url, params=params)
            if response.status_code == 200:
                data = response.json()
                if type(data) is list and len(data) > 0:
                    return data[0].get('adjusted_close')
                elif type(data) is dict and 'code' in data:
                    # API returned error, e.g. {'code': 'TickerNotFound'}
                    return None
                else:
                    return None
            elif response.status_code == 429:
                # Rate limit. Wait and retry.
                time.sleep(5)
            else:
                return None
        except Exception:
            time.sleep(1)
    return None

# %%
# Helper to map tickers to the correct EODHD format/append '.US'. Customize if needed for exceptions.
def get_eodhd_ticker(ticker):
    # Place for any cleaning/formatting per EODHD requirements
    return f"{ticker.upper()}"

# %%
# Function to build close price DataFrame for a single date for all tickers
def build_close_price_dataframe_for_date(tickers, date, api_key, rate_limit_per_min=900, max_workers=12):
    """
    Fetch adjusted close prices for list of tickers for specific date using parallel requests,
    while enforcing a rate limit of 900 requests per minute.

    Returns a DataFrame: one row per ticker, column = date, value = price (float or None if not available).

    Args:
        tickers (list): List of ticker strings.
        date (str): Date string ('YYYY-MM-DD').
        api_key (str): API key for EODHD.
        rate_limit_per_min (int): Max API calls per minute (default 900).
        max_workers (int): Number of parallel threads/processes (default 8).

    Returns:
        pd.DataFrame: Ticker and price info.
    """
    import pandas as pd
    import time
    from concurrent.futures import ThreadPoolExecutor, as_completed
    from threading import BoundedSemaphore

    # Set up a semaphore to allow up to rate_limit_per_min requests per minute
    sem = BoundedSemaphore(rate_limit_per_min)

    # Timestamps of requests to track per-minute limits
    request_times = []

    # Helper function to call API and apply rate limiting
    def fetch_for_ticker(ticker):
        nonlocal request_times
        session = requests.Session()
        mapped_ticker = get_eodhd_ticker(ticker)
        # Rate limiting logic:
        while True:
            now = time.time()
            # Remove timestamps older than 60 seconds
            request_times = [t for t in request_times if now - t < 60]
            if len(request_times) < rate_limit_per_min:
                request_times.append(now)
                break
            time_to_wait = 60 - (now - request_times[0])
            if time_to_wait > 0:
                time.sleep(min(time_to_wait, 0.05))
        price = fetch_adjusted_close(mapped_ticker, date, api_key, session)
        return {
            "TICKER": ticker,
            date: price
        }

    results = []
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_ticker = {executor.submit(fetch_for_ticker, ticker): ticker for ticker in tickers}
        completed = 0
        for future in as_completed(future_to_ticker):
            result = future.result()
            results.append(result)
            completed += 1
            print(f"Fetched {completed}/{len(tickers)}: {result['TICKER']} -> {result[date]}")

    df = pd.DataFrame(results)
    return df

# %%
# Set your API key here
API_KEY = "in env!"  # Set safely/securely

# Select the first date from test_dates
# target_date = test_dates[0]  # e.g. '2025-06-30'
# print(f"Target date: {target_date}")

# # Get unique tickers from russell3000_df
# tickers_list = russell3000_df['TICKER'].str.upper().unique().tolist()
# print(f"Total tickers to fetch: {len(tickers_list)}")

# # Fetch prices for ALL tickers for the first date
# result_df = build_close_price_dataframe_for_date(tickers_list, target_date, API_KEY)

# # Display results
# print(f"\nFetched prices for {len(result_df)} tickers")
# print(result_df.head(20))

# # Show how many have valid prices vs None
# valid_prices = result_df[target_date].notna().sum()
# missing_prices = result_df[target_date].isna().sum()
# print(f"\nValid prices: {valid_prices}, Missing prices: {missing_prices}")

# %%
# For each of the first 25 dates, fetch prices for all tickers and upsert results immediately into the PostgreSQL table 'tickerprices'.
# Each row will include: ticker, date, price, and quarter_end (the nearest quarter-end date to 'date').
# Also, collect per-date statistics and store summary in a DataFrame at the end.
# Use only psycopg2, since SQLAlchemy is NOT available.
# The code will check for a closed connection and reconnect if needed.
# All comments are in English.

from psycopg2.extras import execute_batch
import datetime

def map_to_nearest_quarter_end(date_str):
    """Map a string date (YYYY-MM-DD) to the closest quarter-end in the same year."""
    date = pd.to_datetime(date_str)
    quarter_ends = [
        datetime.date(date.year, 3, 31),
        datetime.date(date.year, 6, 30),
        datetime.date(date.year, 9, 30),
        datetime.date(date.year, 12, 31),
    ]
    closest = min(quarter_ends, key=lambda q: abs(date.date() - q))
    return str(closest)

def ensure_conn_open(conn):
    """Reconnects if the psycopg2 connection has closed."""
    try:
        # Try a simple operation to check connection
        if conn.closed != 0:
            # Reconnect using saved parameters, adjust as needed
            return psycopg2.connect(
                dbname="Social_13F",
                user="postgres",
                password="Test123",
                host="127.0.0.1",
                port=5432
            )
        else:
            return conn
    except Exception:
        # If any error, force reconnect
        return psycopg2.connect(
            dbname="Social_13F",
            user="postgres",
            password="Test123",
            host="127.0.0.1",
            port=5432
        )

stats = []
tickers_list = russell3000_df['TICKER'].str.upper().unique().tolist()

for idx, target_date in enumerate(test_dates[26:]):
    print(f"Fetching for {target_date} ...")

    # Fetch the price DataFrame for the current date
    date_prices_df = build_close_price_dataframe_for_date(tickers_list, target_date, API_KEY)
    date_prices_df["date"] = target_date
    date_prices_df = date_prices_df.rename(columns={target_date: "price"})
    date_prices_df = date_prices_df[["TICKER", "date", "price"]]

    # Compute quarter_end column for each entry
    date_prices_df["quarter_end"] = date_prices_df["date"].apply(map_to_nearest_quarter_end)

    # Prepare tuples for database insertion
    data_tuples = [tuple(x) for x in date_prices_df[["TICKER", "date", "price", "quarter_end"]].to_numpy()]

    # Compose insert statement
    insert_stmt = """
        INSERT INTO tickerprices (ticker, date, price, quarter_end)
        VALUES (%s, %s, %s, %s)
        ON CONFLICT (ticker, date) DO UPDATE SET price=EXCLUDED.price, quarter_end=EXCLUDED.quarter_end;
    """

    # Ensure connection is open before using
    conn = ensure_conn_open(conn)
    with conn.cursor() as cur:
        execute_batch(cur, insert_stmt, data_tuples, page_size=500)
        conn.commit()

    # Per-date stats tracking
    attempted = len(date_prices_df)
    succeeded = date_prices_df["price"].notna().sum()
    success_rate = succeeded / attempted if attempted > 0 else 0.0
    print(f"Date {target_date}: Attempted: {attempted}, Succeeded: {succeeded}, Success Rate: {success_rate:.2%}")

    stats.append({
        "date": target_date,
        "attempted": attempted,
        "succeeded": succeeded,
        "success_rate": success_rate
    })

# Build statistics DataFrame
stats_df = pd.DataFrame(stats)
print("\nStatistics per date:")
print(stats_df)
# Out:
# Fetching for 2019-12-31 ...
# Fetched 1/2892: AAPL -> 70.8517
# Fetched 2/2892: MSFT -> 149.7332
# Fetched 3/2892: META -> 203.8262
# Fetched 4/2892: NVDA -> 5.8563
# Fetched 5/2892: GOOGL -> 66.4673
# Fetched 6/2892: AVGO -> 27.1895
# Fetched 7/2892: GOOG -> 66.3533
# Fetched 8/2892: AMZN -> 92.392
# Fetched 9/2892: TSLA -> 27.8886
# Fetched 10/2892: JPM -> 118.1407
# Fetched 11/2892: BRK/B -> None
# Fetched 12/2892: LLY -> 122.2984
# Fetched 13/2892: XOM -> 52.8008
# Fetched 14/2892: V -> 180.093
# Fetched 15/2892: MA -> 288.6876
# Fetched 16/2892: JNJ -> 123.2078
# Fetched 17/2892: NFLX -> 32.357
# Fetched 18/2892: PLTR -> None
# Fetched 19/2892: COST -> 268.7191
# Fetched 20/2892: AMD -> 45.86
# Fetched 21/2892: BAC -> 30.398
# Fetched 22/2892: ABBV -> 69.0318
# Fetched 23/2892: WMT -> 36.4032
# Fetched 24/2892: HD -> 188.8823
# Fetched 25/2892: PG -> 107.5366
# Fetched 26/2892: ORCL -> 48.554
# Fetched 27/2892: GE -> 54.0989
# Fetched 28/2892: CSCO -> 40.0106
# Fetched 29/2892: MU -> 52.473
# Fetched 30/2892: IBM -> 98.9951
# Fetched 31/2892: CVX -> 92.2139
# Fetched 32/2892: KO -> 46.0446
# Fetched 33/2892: WFC -> 46.0952
# Fetched 34/2892: CAT -> 130.3356
# Fetched 35/2892: UNH -> 266.5993
# Fetched 36/2892: MRK -> 71.7672
# Fetched 37/2892: GS -> 199.3695
# Fetched 38/2892: PM -> 62.6863
# Fetched 39/2892: RTX -> 76.5578
# Fetched 40/2892: CRM -> 160.6876
# Fetched 41/2892: ISRG -> 197.0501
# Fetched 42/2892: PEP -> 113.8219
# Fetched 43/2892: AXP -> 114.9796
# Fetched 44/2892: TMO -> 319.8616
# Fetched 45/2892: LRCX -> 27.2375
# Fetched 46/2892: MCD -> 171.9928
# Fetched 47/2892: AMAT -> 57.6766
# Fetched 48/2892: ABT -> 78.1235
# Fetched 49/2892: MS -> 42.3083
# Fetched 50/2892: LIN -> 195.3676
# Fetched 51/2892: C -> 64.2336
# Fetched 52/2892: T -> 19.3095
# Fetched 53/2892: AMGN -> 200.3921
# Fetched 54/2892: DIS -> 141.3024
# Fetched 55/2892: UBER -> 29.74
# Fetched 56/2892: QCOM -> 77.2437
# Fetched 57/2892: NEE -> 52.1961
# Fetched 58/2892: INTC -> 52.7951
# Fetched 59/2892: VZ -> 43.5749
# Fetched 60/2892: INTU -> 252.3685
# Fetched 61/2892: APH -> 25.5706
# Fetched 62/2892: TJX -> 56.4906
# Fetched 63/2892: NOW -> 56.464
# Fetched 64/2892: GEV -> None
# Fetched 65/2892: BKNG -> 2020.6667
# Fetched 66/2892: BLK -> 434.7831
# Fetched 67/2892: SCHW -> 43.7541
# Fetched 68/2892: KLAC -> 165.7995
# Fetched 69/2892: GILD -> 51.5367
# Fetched 70/2892: SPGI -> 259.7682
# Fetched 71/2892: TXN -> 108.1173
# Fetched 72/2892: DHR -> 132.5593
# Fetched 73/2892: ACN -> 191.6522
# Fetched 74/2892: PFE -> 27.984
# Fetched 75/2892: BSX -> 45.22
# Fetched 76/2892: APP -> None
# Fetched 77/2892: WELL -> 68.2768
# Fetched 78/2892: UNP -> 158.2699
# Fetched 79/2892: COF -> 92.8285
# Fetched 80/2892: ETN -> 84.2893
# Fetched 81/2892: MDT -> 95.4275
# Fetched 82/2892: LOW -> 107.3301
# Fetched 83/2892: ADBE -> 329.81
# Fetched 84/2892: ADI -> 106.6655
# Fetched 85/2892: BA -> 323.8333
# Fetched 86/2892: ANET -> 12.7125
# Fetched 87/2892: PGR -> 63.2899
# Fetched 88/2892: PANW -> 38.5416
# Fetched 89/2892: SYK -> 196.9409
# Fetched 90/2892: CRWD -> 49.87
# Fetched 91/2892: HON -> 147.1705
# Fetched 92/2892: PLD -> 75.5052
# Fetched 93/2892: CEG -> None
# Fetched 94/2892: COP -> 52.534
# Fetched 95/2892: MCK -> 132.8633
# Fetched 96/2892: DE -> 159.5718
# Fetched 97/2892: VRTX -> 218.95
# Fetched 98/2892: PH -> 189.0545
# Fetched 99/2892: CB -> 140.5005
# Fetched 100/2892: BX -> 45.5294
# Fetched 101/2892: ADP -> 150.0422
# Fetched 102/2892: CME -> 160.813
# Fetched 103/2892: CVS -> 61.2336
# Fetched 104/2892: BMY -> 51.2565
# Fetched 105/2892: MO -> 30.9294
# Fetched 106/2892: NEM -> 36.4545
# Fetched 107/2892: SO -> 50.5335
# Fetched 108/2892: SBUX -> 76.9698
# Fetched 109/2892: CMCSA -> 38.2518
# Fetched 110/2892: LMT -> 330.8302
# Fetched 111/2892: DUK -> 71.8364
# Fetched 112/2892: TMUS -> 75.762
# Fetched 113/2892: HOOD -> None
# Fetched 114/2892: TT -> 94.7718
# Fetched 115/2892: SPOT -> 149.55
# Fetched 116/2892: MMM -> 118.2823
# Fetched 117/2892: HCA -> 140.7651
# Fetched 118/2892: MMC -> 101.6976
# Fetched 119/2892: ICE -> 85.7141
# Fetched 120/2892: ORLY -> 29.2175
# Fetched 121/2892: GD -> 153.1994
# Fetched 122/2892: AMT -> 194.6945
# Fetched 123/2892: CDNS -> 69.36
# Fetched 124/2892: KKR -> 27.4545
# Fetched 125/2892: CRH -> 34.4876
# Fetched 126/2892: HWM -> 23.2632
# Fetched 127/2892: REGN -> 373.409
# Fetched 128/2892: WM -> 103.3582
# Fetched 129/2892: BK -> 42.1744
# Fetched 130/2892: SHW -> 184.4156
# Fetched 131/2892: NOC -> 311.5209
# Fetched 132/2892: SNOW -> None
# Fetched 133/2892: MRVL -> 25.8679
# Fetched 134/2892: SNPS -> 139.2
# Fetched 135/2892: JCI -> 35.7204
# Fetched 136/2892: ELV -> 278.4675
# Fetched 137/2892: USB -> 45.7777
# Fetched 138/2892: PNC -> 127.9225
# Fetched 139/2892: TDG -> 463.1336
# Fetched 140/2892: MCO -> 225.8265
# Fetched 141/2892: NKE -> 93.4219
# Fetched 142/2892: EMR -> 66.7134
# Fetched 143/2892: MDLZ -> 47.4824
# Fetched 144/2892: AON -> 198.3941
# Fetched 145/2892: WMB -> 17.0718
# Fetched 146/2892: EQIX -> 522.159
# Fetched 147/2892: CI -> 187.0364
# Fetched 148/2892: UPS -> 92.1547
# Fetched 149/2892: DASH -> None
# Fetched 150/2892: ITW -> 155.9692
# Fetched 151/2892: MAR -> 145.456
# Fetched 152/2892: GM -> 34.8873
# Fetched 153/2892: ECL -> 181.0144
# Fetched 154/2892: PWR -> 40.1714
# Fetched 155/2892: CMI -> 154.118
# Fetched 156/2892: VRT -> 10.9765
# Fetched 157/2892: COR -> 79.0354
# Fetched 158/2892: RCL -> 129.9149
# Fetched 159/2892: CSX -> 22.2547
# Fetched 160/2892: NSC -> 171.6393
# Fetched 161/2892: TRV -> 120.5574
# Fetched 162/2892: AZO -> 1191.31
# Fetched 163/2892: GLW -> 24.5921
# Fetched 164/2892: AEP -> 76.2048
# Fetched 165/2892: HLT -> 109.3689
# Fetched 166/2892: ADSK -> 183.46
# Fetched 167/2892: CL -> 59.7731
# Fetched 168/2892: CTAS -> 63.7239
# Fetched 169/2892: AJG -> 88.784
# Fetched 170/2892: SRE -> 62.2818
# Fetched 171/2892: NET -> 17.06
# Fetched 172/2892: FCX -> 12.2348
# Fetched 173/2892: IDXX -> 261.13
# Fetched 174/2892: MSI -> 149.0624
# Fetched 175/2892: VST -> 20.0637
# Fetched 176/2892: SPG -> 106.5419
# Fetched 177/2892: TFC -> 42.6764
# Fetched 178/2892: PYPL -> 107.9205
# Fetched 179/2892: MPC -> 49.9714
# Fetched 180/2892: FDX -> 135.323
# Fetched 181/2892: EOG -> 64.6682
# Fetched 182/2892: NU -> None
# Fetched 183/2892: RBLX -> None
# Fetched 184/2892: APD -> 204.6309
# Fetched 185/2892: ZTS -> 125.8075
# Fetched 186/2892: COIN -> None
# Fetched 187/2892: WDC -> 46.7867
# Fetched 188/2892: ROST -> 109.7632
# Fetched 189/2892: ALL -> 97.3212
# Fetched 190/2892: ALNY -> 115.17
# Fetched 191/2892: WBD -> 32.74
# Fetched 192/2892: PSX -> 86.9697
# Fetched 193/2892: BDX -> 241.5371
# Fetched 194/2892: VLO -> 73.3117
# Fetched 195/2892: APO -> 40.4924
# Fetched 196/2892: PCAR -> 42.7358
# Fetched 197/2892: DLR -> 97.4801
# Fetched 198/2892: AFL -> 45.8188
# Fetched 199/2892: D -> 63.7789
# Fetched 200/2892: KMI -> 14.7641
# Fetched 201/2892: O -> 52.8288
# Fetched 202/2892: URI -> 161.5171
# Fetched 203/2892: MNST -> 31.775
# Fetched 204/2892: F -> 6.9368
# Fetched 205/2892: LHX -> 175.5515
# Fetched 206/2892: FTNT -> 21.352
# Fetched 207/2892: CAH -> 43.2231
# Fetched 208/2892: EA -> 104.5315
# Fetched 209/2892: EW -> 77.7633
# Fetched 210/2892: BKR -> 21.6246
# Fetched 211/2892: ABNB -> None
# Fetched 212/2892: CVNA -> 92.05
# Fetched 213/2892: FERG -> 79.5236
# Fetched 214/2892: DDOG -> 37.78
# Fetched 215/2892: XEL -> 52.7869
# Fetched 216/2892: CBRE -> 61.29
# Fetched 217/2892: ROP -> 342.2911
# Fetched 218/2892: EXC -> 26.2323
# Fetched 219/2892: WDAY -> 164.45
# Fetched 220/2892: MSTR -> 14.263
# Fetched 221/2892: FAST -> 15.8401
# Fetched 222/2892: CMG -> 16.7422
# Fetched 223/2892: CTVA -> 27.4413
# Fetched 224/2892: LNG -> 58.517
# Fetched 225/2892: AME -> 95.8065
# Fetched 226/2892: TTWO -> 122.43
# Fetched 227/2892: OKE -> 50.6284
# Fetched 228/2892: ROK -> 182.4543
# Fetched 229/2892: RSG -> 82.6022
# Fetched 230/2892: AIG -> 43.9179
# Fetched 231/2892: CARR -> None
# Fetched 232/2892: A -> 81.9337
# Fetched 233/2892: ETR -> 48.1224
# Fetched 234/2892: AMP -> 150.223
# Fetched 235/2892: PSA -> 165.331
# Fetched 236/2892: AU -> 19.5625
# Fetched 237/2892: MPWR -> 170.2237
# Fetched 238/2892: MET -> 41.6563
# Fetched 239/2892: MSCI -> 243.24
# Fetched 240/2892: YUM -> 90.0126
# Fetched 241/2892: FICO -> 374.68
# Fetched 242/2892: DHI -> 49.5928
# Fetched 243/2892: GWW -> 314.5914
# Fetched 244/2892: DAL -> 56.5012
# Fetched 245/2892: PEG -> 48.1548
# Fetched 246/2892: TGT -> 109.3672
# Fetched 247/2892: DELL -> 23.869
# Fetched 248/2892: KR -> 21.3722
# Fetched 249/2892: AXON -> 73.28
# Fetched 250/2892: VMC -> 135.4376
# Fetched 251/2892: INSM -> 23.88
# Fetched 252/2892: IQV -> 154.51
# Fetched 253/2892: HIG -> 53.1956
# Fetched 254/2892: CCI -> 109.3393
# Fetched 255/2892: CTSH -> 56.6334
# Fetched 256/2892: PRU -> 69.219
# Fetched 257/2892: EBAY -> 32.6215
# Fetched 258/2892: EQT -> 10.1806
# Fetched 259/2892: NDAQ -> 32.8091
# Fetched 260/2892: TRGP -> 35.3656
# Fetched 261/2892: RMD -> 147.2347
# Fetched 262/2892: MLM -> 268.3053
# Fetched 263/2892: SYY -> 72.8822
# Fetched 264/2892: NUE -> 50.087
# Fetched 265/2892: GEHC -> None
# Fetched 266/2892: VTR -> 45.8188
# Fetched 267/2892: FLUT -> 113.2824
# Fetched 268/2892: XYZ -> 62.56
# Fetched 269/2892: KMB -> 111.2259
# Fetched 270/2892: KDP -> 25.0787
# Fetched 271/2892: ED -> 72.7741
# Fetched 272/2892: PAYX -> 71.4417
# Fetched 273/2892: WEC -> 75.97
# Fetched 274/2892: WAB -> 75.0772
# Fetched 275/2892: VEEV -> 140.66
# Fetched 276/2892: PCG -> 10.7454
# Fetched 277/2892: OTIS -> None
# Fetched 278/2892: CPNG -> None
# Fetched 279/2892: FIS -> 122.3851
# Fetched 280/2892: XYL -> 73.365
# Fetched 281/2892: CPRT -> 22.73
# Fetched 282/2892: ACGL -> 40.784
# Fetched 283/2892: KEYS -> 102.63
# Fetched 284/2892: FIX -> 48.1969
# Fetched 285/2892: STT -> 65.6057
# Fetched 286/2892: SOFI -> None
# Fetched 287/2892: FISV -> 115.63
# Fetched 288/2892: UAL -> 88.09
# Fetched 289/2892: KVUE -> None
# Fetched 290/2892: IR -> 35.0563
# Fetched 291/2892: GRMN -> 85.2833
# Fetched 292/2892: NRG -> 33.1465
# Fetched 293/2892: MTD -> 793.28
# Fetched 294/2892: WTW -> 186.3851
# Fetched 295/2892: EXPE -> 106.877
# Fetched 296/2892: NTRA -> 33.69
# Fetched 297/2892: VRSK -> 143.7305
# Fetched 298/2892: SNDK -> None
# Fetched 299/2892: VICI -> 18.5356
# Fetched 300/2892: MTB -> 139.5119
# Fetched 301/2892: OXY -> 37.6122
# Fetched 302/2892: ARES -> 29.3598
# Fetched 303/2892: HUM -> 347.7104
# Fetched 304/2892: TER -> 66.4854
# Fetched 305/2892: SYF -> 30.9819
# Fetched 306/2892: FITB -> 24.2159
# Fetched 307/2892: ADM -> 39.0017
# Fetched 308/2892: TSCO -> 17.0099
# Fetched 309/2892: FANG -> 72.5633
# Fetched 310/2892: HPE -> 13.0921
# Fetched 311/2892: CIEN -> 42.69
# Fetched 312/2892: AEE -> 64.6402
# Fetched 313/2892: CSGP -> 59.83
# Fetched 314/2892: RJF -> 54.636
# Fetched 315/2892: LPLA -> 88.6989
# Fetched 316/2892: MCHP -> 46.6956
# Fetched 317/2892: DTE -> 90.2266
# Fetched 318/2892: EXR -> 84.2
# Fetched 319/2892: ATO -> 96.4099
# Fetched 320/2892: CCL -> 50.2436
# Fetched 321/2892: FSLR -> 55.96
# Fetched 322/2892: LEN -> 45.4716
# Fetched 323/2892: HSY -> 127.7114
# Fetched 324/2892: PPL -> 27.9827
# Fetched 325/2892: EME -> 84.3701
# Fetched 326/2892: CBOE -> 110.1237
# Fetched 327/2892: IBKR -> 11.5521
# Fetched 328/2892: BIIB -> 296.73
# Fetched 329/2892: EXE -> None
# Fetched 330/2892: BR -> 111.6157
# Fetched 331/2892: EFX -> 133.8384
# Fetched 332/2892: FE -> 37.8262
# Fetched 333/2892: MDB -> 131.61
# Fetched 334/2892: STE -> 144.1664
# Fetched 335/2892: CRDO -> None
# Fetched 336/2892: CNP -> 23.1858
# Fetched 337/2892: MKL -> 1143.17
# Fetched 338/2892: GIS -> 43.5303
# Fetched 339/2892: AVB -> 170.0633
# Fetched 340/2892: HBAN -> 11.3764
# Fetched 341/2892: CINF -> 89.9363
# Fetched 342/2892: AWK -> 109.6729
# Fetched 343/2892: IRM -> 23.4206
# Fetched 344/2892: DOV -> 106.1074
# Fetched 345/2892: COHR -> 33.67
# Fetched 346/2892: ODFL -> 61.5483
# Fetched 347/2892: PHM -> 36.4864
# Fetched 348/2892: RDDT -> None
# Fetched 349/2892: NTRS -> 88.1846
# Fetched 350/2892: DXCM -> 54.685
# Fetched 351/2892: ES -> 68.4013
# Fetched 352/2892: ZS -> 46.5
# Fetched 353/2892: LDOS -> 90.3879
# Fetched 354/2892: ULTA -> 253.14
# Fetched 355/2892: VLTO -> None
# Fetched 356/2892: TEAM -> 120.34
# Fetched 357/2892: DG -> 143.5128
# Fetched 358/2892: WAT -> 233.65
# Fetched 359/2892: STLD -> 30.276
# Fetched 360/2892: CFG -> 30.9943
# Fetched 361/2892: QSR -> 51.5758
# Fetched 362/2892: EQR -> 64.8887
# Fetched 363/2892: K -> 52.3465
# Fetched 364/2892: TDY -> 346.54
# Fetched 365/2892: DVN -> 18.8683
# Fetched 366/2892: BE -> 7.47
# Fetched 367/2892: RF -> 13.405
# Fetched 368/2892: HUBB -> 132.4989
# Fetched 369/2892: EL -> 190.8977
# Fetched 370/2892: OMC -> 65.0985
# Fetched 371/2892: HPQ -> 16.7137
# Fetched 372/2892: PODD -> 171.2
# Fetched 373/2892: PPG -> 118.7346
# Fetched 374/2892: TPR -> 23.4918
# Fetched 375/2892: WRB -> 27.0512
# Fetched 376/2892: LITE -> 79.3
# Fetched 377/2892: ZM -> 68.04
# Fetched 378/2892: HAL -> 21.9272
# Fetched 379/2892: LH -> 138.8285
# Fetched 380/2892: CMS -> 52.5067
# Fetched 381/2892: BRO -> 37.8659
# Fetched 382/2892: EIX -> 57.7471
# Fetched 383/2892: NTAP -> 52.9168
# Fetched 384/2892: TROW -> 94.9023
# Fetched 385/2892: JBL -> 40.1698
# Fetched 386/2892: FLEX -> 7.2261
# Fetched 387/2892: DLTR -> 94.05
# Fetched 388/2892: KHC -> 24.1458
# Fetched 389/2892: UTHR -> 88.08
# Fetched 390/2892: NVR -> 3808.41
# Fetched 391/2892: WSM -> 32.5113
# Fetched 392/2892: VRSN -> 191.0135
# Fetched 393/2892: DGX -> 94.2174
# Fetched 394/2892: LVS -> 64.6318
# Fetched 395/2892: CW -> 137.1585
# Fetched 396/2892: ON -> 24.38
# Fetched 397/2892: CASY -> 153.0021
# Fetched 398/2892: CHD -> 65.5288
# Fetched 399/2892: DRI -> 92.0859
# Fetched 400/2892: LYV -> 71.47
# Fetched 401/2892: PTC -> 74.89
# Fetched 402/2892: NI -> 22.7418
# Fetched 403/2892: SBAC -> 223.2493
# Fetched 404/2892: ILMN -> 322.7043
# Fetched 405/2892: IP -> 31.9707
# Fetched 406/2892: FWONK -> 44.4244
# Fetched 407/2892: CTRA -> 13.1304
# Fetched 408/2892: TYL -> 300.02
# Fetched 409/2892: EXPD -> 72.74
# Fetched 410/2892: ALAB -> None
# Fetched 411/2892: WST -> 148.0161
# Fetched 412/2892: STZ -> 171.8513
# Fetched 413/2892: CPAY -> 287.72
# Fetched 414/2892: AMCR -> 8.1921
# Fetched 415/2892: BAM -> None
# Fetched 416/2892: TRMB -> 41.69
# Fetched 417/2892: LULU -> 231.67
# Fetched 418/2892: ZBH -> 138.2853
# Fetched 419/2892: CNC -> 62.87
# Fetched 420/2892: AFRM -> None
# Fetched 421/2892: CDW -> 132.8307
# Fetched 422/2892: HEI/A -> None
# Fetched 423/2892: THC -> 38.03
# Fetched 424/2892: PFG -> 43.6818
# Fetched 425/2892: EXAS -> 92.48
# Fetched 426/2892: RKT -> None
# Fetched 427/2892: HUBS -> 158.5
# Fetched 428/2892: CHRW -> 67.8052
# Fetched 429/2892: SW -> 29.6184
# Fetched 430/2892: L -> 51.1931
# Fetched 431/2892: FTI -> 15.334
# Fetched 432/2892: SGI -> 20.6832
# Fetched 433/2892: GPN -> 174.0294
# Fetched 434/2892: RBA -> 38.3662
# Fetched 435/2892: SSNC -> 57.0807
# Fetched 436/2892: TWLO -> 98.28
# Fetched 437/2892: GWRE -> 109.77
# Fetched 438/2892: FTV -> 46.8743
# Fetched 439/2892: PKG -> 93.4032
# Fetched 440/2892: GPC -> 89.5177
# Fetched 441/2892: USFD -> 41.89
# Fetched 442/2892: EVRG -> 51.4439
# Fetched 443/2892: IFF -> 109.8365
# Fetched 444/2892: LNT -> 45.2428
# Fetched 445/2892: TLN -> None
# Fetched 446/2892: WWD -> 114.1098
# Fetched 447/2892: FCNCA -> 521.5205
# Fetched 448/2892: GDDY -> 67.92
# Fetched 449/2892: CHTR -> 485.08
# Fetched 450/2892: FTAI -> 12.6034
# Fetched 451/2892: TTD -> 25.978
# Fetched 452/2892: KEY -> 15.09
# Fetched 453/2892: NVT -> 22.7475
# Fetched 454/2892: RKLB -> None
# Fetched 455/2892: INVH -> 25.1684
# Fetched 456/2892: IT -> 154.1
# Fetched 457/2892: SNA -> 144.6455
# Fetched 458/2892: SMCI -> 2.402
# Fetched 459/2892: PNR -> 42.1697
# Fetched 460/2892: ROL -> 20.6477
# Fetched 461/2892: MKC -> 75.4442
# Fetched 462/2892: DOW -> 39.182
# Fetched 463/2892: APTV -> 94.7291
# Fetched 464/2892: RGLD -> 113.9617
# Fetched 465/2892: ESS -> 245.5357
# Fetched 466/2892: HOLX -> 52.21
# Fetched 467/2892: DD -> 23.5936
# Fetched 468/2892: INCY -> 87.32
# Fetched 469/2892: TPL -> 77.0179
# Fetched 470/2892: TRU -> 83.2014
# Fetched 471/2892: XPO -> 27.5493
# Fetched 472/2892: FN -> 64.84
# Fetched 473/2892: LUV -> 50.0257
# Fetched 474/2892: BWXT -> 57.5896
# Fetched 475/2892: TSN -> 76.2279
# Fetched 476/2892: SUI -> 124.3803
# Fetched 477/2892: WY -> 24.248
# Fetched 478/2892: J -> 70.1307
# Fetched 479/2892: DKNG -> 10.7
# Fetched 480/2892: BURL -> 228.03
# Fetched 481/2892: MAA -> 106.3535
# Fetched 482/2892: LII -> 226.8667
# Fetched 483/2892: JLL -> 174.09
# Fetched 484/2892: COO -> 80.2684
# Fetched 485/2892: TOST -> None
# Fetched 486/2892: FNF -> 35.4042
# Fetched 487/2892: PINS -> 18.64
# Fetched 488/2892: CRS -> 44.6644
# Fetched 489/2892: BBY -> 69.0541
# Fetched 490/2892: ALB -> 67.6967
# Fetched 491/2892: RPRX -> None
# Fetched 492/2892: TXT -> 44.2633
# Fetched 493/2892: PFGC -> 51.48
# Fetched 494/2892: RS -> 107.6773
# Fetched 495/2892: NBIX -> 107.49
# Fetched 496/2892: NLY -> 17.0788
# Fetched 497/2892: WPC -> 55.004
# Fetched 498/2892: EWBC -> 41.7927
# Fetched 499/2892: APG -> 7.0333
# Fetched 500/2892: GEN -> 12.9707
# Fetched 501/2892: ITT -> 69.1847
# Fetched 502/2892: ALLE -> 114.5784
# Fetched 503/2892: CG -> 26.4256
# Fetched 504/2892: FOXA -> 34.2031
# Fetched 505/2892: EQH -> 21.2362
# Fetched 506/2892: RL -> 104.9007
# Fetched 507/2892: ATI -> 20.66
# Fetched 508/2892: DOCU -> 74.11
# Fetched 509/2892: KIM -> 15.928
# Fetched 510/2892: RBC -> 150.1024
# Fetched 511/2892: GGG -> 48.2995
# Fetched 512/2892: FFIV -> 139.65
# Fetched 513/2892: BALL -> 60.2784
# Fetched 514/2892: MAS -> 43.1646
# Fetched 515/2892: ACM -> 41.607
# Fetched 516/2892: TOL -> 36.8589
# Fetched 517/2892: CSL -> 150.8587
# Fetched 518/2892: RPM -> 68.7896
# Fetched 519/2892: Z -> 45.94
# Fetched 520/2892: JBHT -> 110.4909
# Fetched 521/2892: IONQ -> None
# Fetched 522/2892: RVMD -> None
# Fetched 523/2892: MTZ -> 64.16
# Fetched 524/2892: CACI -> 249.99
# Fetched 525/2892: U -> None
# Fetched 526/2892: AVY -> 118.038
# Fetched 527/2892: DPZ -> 273.4448
# Fetched 528/2892: CLX -> 128.2376
# Fetched 529/2892: OHI -> 25.9982
# Fetched 530/2892: TKO -> 59.8634
# Fetched 531/2892: MEDP -> 84.06
# Fetched 532/2892: UHS -> 139.5163
# Fetched 533/2892: OKTA -> 115.37
# Fetched 534/2892: HEI -> 113.3404
# Fetched 535/2892: EG -> 241.5294
# Fetched 536/2892: IEX -> 159.8197
# Fetched 537/2892: LECO -> 87.6637
# Fetched 538/2892: RIVN -> None
# Fetched 539/2892: DT -> 25.3
# Fetched 540/2892: DKS -> 41.0027
# Fetched 541/2892: BG -> 48.1762
# Fetched 542/2892: IONS -> 60.41
# Fetched 543/2892: DECK -> 28.1433
# Fetched 544/2892: REG -> 48.9956
# Fetched 545/2892: BLD -> 103.08
# Fetched 546/2892: JKHY -> 135.4783
# Fetched 547/2892: UNM -> 23.2045
# Fetched 548/2892: AKAM -> 86.38
# Fetched 549/2892: ZBRA -> 255.44
# Fetched 550/2892: WCC -> 57.7377
# Fetched 551/2892: GH -> 78.14
# Fetched 552/2892: NDSN -> 152.6536
# Fetched 553/2892: TW -> 45.1634
# Fetched 554/2892: DOC -> 21.6791
# Fetched 555/2892: CF -> 41.2129
# Fetched 556/2892: RVTY -> 95.7315
# Fetched 557/2892: RGA -> 142.6667
# Fetched 558/2892: VTRS -> 16.43
# Fetched 559/2892: SOLV -> None
# Fetched 560/2892: KTOS -> 18.01
# Fetched 561/2892: LYB -> 63.4927
# Fetched 562/2892: ROKU -> 133.9
# Fetched 563/2892: WSO -> 150.9413
# Fetched 564/2892: DTM -> None
# Fetched 565/2892: HII -> 218.9984
# Fetched 566/2892: NTNX -> 31.26
# Fetched 567/2892: SF -> 36.626
# Fetched 568/2892: BLDR -> 25.41
# Fetched 569/2892: UDR -> 37.1669
# Fetched 570/2892: HST -> 15.061
# Fetched 571/2892: RNR -> 186.8528
# Fetched 572/2892: ELS -> 60.2307
# Fetched 573/2892: MLI -> 14.4924
# Fetched 574/2892: NWSA -> 13.3002
# Fetched 575/2892: SNX -> 60.3493
# Fetched 576/2892: GLPI -> 30.2925
# Fetched 577/2892: EVR -> 65.7348
# Fetched 578/2892: LAMR -> 67.5576
# Fetched 579/2892: BJ -> 22.74
# Fetched 580/2892: VIK -> None
# Fetched 581/2892: EXEL -> 17.62
# Fetched 582/2892: EHC -> 51.446
# Fetched 583/2892: TXRH -> 51.312
# Fetched 584/2892: BXP -> 102.3011
# Fetched 585/2892: ENTG -> 48.8918
# Fetched 586/2892: CPT -> 86.4815
# Fetched 587/2892: AIZ -> 117.7372
# Fetched 588/2892: CLH -> 85.75
# Fetched 589/2892: ELAN -> 29.45
# Fetched 590/2892: QXO -> 20.8837
# Fetched 591/2892: ALLY -> 25.2148
# Fetched 592/2892: AYI -> 135.3817
# Fetched 593/2892: FHN -> 13.1438
# Fetched 594/2892: CCK -> 68.931
# Fetched 595/2892: SCCO -> 31.9185
# Fetched 596/2892: GL -> 99.9765
# Fetched 597/2892: BBIO -> 35.05
# Fetched 598/2892: SCI -> 41.7304
# Fetched 599/2892: WTRG -> 39.7882
# Fetched 600/2892: HAS -> 83.6478
# Fetched 601/2892: SWK -> 137.904
# Fetched 602/2892: MTSI -> 26.6
# Fetched 603/2892: SJM -> 85.5648
# Fetched 604/2892: WMS -> 37.7207
# Fetched 605/2892: MDGL -> 91.11
# Fetched 606/2892: AMH -> 23.0782
# Fetched 607/2892: PEN -> 164.27
# Fetched 608/2892: AGNC -> 8.1847
# Fetched 609/2892: CDE -> 8.08
# Fetched 610/2892: PNW -> 69.3762
# Fetched 611/2892: ASTS -> 9.87
# Fetched 612/2892: DAY -> 67.88
# Fetched 613/2892: AA -> 20.5459
# Fetched 614/2892: MKSI -> 105.1255
# Fetched 615/2892: AR -> 2.85
# Fetched 616/2892: BMRN -> 84.55
# Fetched 617/2892: MANH -> 79.75
# Fetched 618/2892: FDS -> 253.4388
# Fetched 619/2892: WYNN -> 133.8568
# Fetched 620/2892: ORI -> 14.4802
# Fetched 621/2892: W -> 90.37
# Fetched 622/2892: OVV -> 19.5816
# Fetched 623/2892: DCI -> 52.4849
# Fetched 624/2892: GMED -> 58.88
# Fetched 625/2892: NYT -> 30.4455
# Fetched 626/2892: ENSG -> 44.6765
# Fetched 627/2892: JAZZ -> 149.28
# Fetched 628/2892: SPXC -> 50.88
# Fetched 629/2892: CMA -> 53.3398
# Fetched 630/2892: EPAM -> 212.16
# Fetched 631/2892: IOT -> None
# Fetched 632/2892: RMBS -> 13.775
# Fetched 633/2892: QGEN -> 32.7184
# Fetched 634/2892: STRL -> 14.08
# Fetched 635/2892: TECH -> 53.2711
# Fetched 636/2892: BAH -> 64.086
# Fetched 637/2892: ALGN -> 279.04
# Fetched 638/2892: REXR -> 38.6381
# Fetched 639/2892: WBS -> 43.0574
# Fetched 640/2892: DY -> 47.15
# Fetched 641/2892: HL -> 3.2939
# Fetched 642/2892: AES -> 16.0029
# Fetched 643/2892: AIT -> 62.1059
# Fetched 644/2892: SWKS -> 104.6946
# Fetched 645/2892: SATS -> 43.31
# Fetched 646/2892: PR -> 4.073
# Fetched 647/2892: OKLO -> None
# Fetched 648/2892: RRX -> 76.7191
# Fetched 649/2892: ARMK -> 29.1042
# Fetched 650/2892: BWA -> 34.7982
# Fetched 651/2892: ONON -> None
# Fetched 652/2892: EGP -> 111.8956
# Fetched 653/2892: OC -> 59.1157
# Fetched 654/2892: BAX -> 74.2832
# Fetched 655/2892: LSCC -> 19.14
# Fetched 656/2892: HLI -> 43.5657
# Fetched 657/2892: PLNT -> 74.68
# Fetched 658/2892: RRC -> 4.6774
# Fetched 659/2892: FLS -> 43.6234
# Fetched 660/2892: FYBR -> None
# Fetched 661/2892: GME -> 1.52
# Fetched 662/2892: CNM -> None
# Fetched 663/2892: ARE -> 128.0248
# Fetched 664/2892: OGE -> 33.943
# Fetched 665/2892: MRNA -> 19.56
# Fetched 666/2892: AAL -> 28.5744
# Fetched 667/2892: IDCC -> 48.597
# Fetched 668/2892: OWL -> None
# Fetched 669/2892: GTLS -> 67.49
# Fetched 670/2892: TTEK -> 16.5848
# Fetched 671/2892: AFG -> 62.9423
# Fetched 672/2892: RGEN -> 92.5
# Fetched 673/2892: CR -> None
# Fetched 674/2892: HQY -> 74.07
# Fetched 675/2892: IVZ -> 13.7325
# Fetched 676/2892: FIVE -> 127.86
# Fetched 677/2892: WTFC -> 63.5934
# Fetched 678/2892: GNRC -> 100.59
# Fetched 679/2892: JEF -> 17.4012
# Fetched 680/2892: APA -> 22.0775
# Fetched 681/2892: AVAV -> 61.74
# Fetched 682/2892: WAL -> 50.2383
# Fetched 683/2892: HALO -> 17.73
# Fetched 684/2892: POOL -> 198.5492
# Fetched 685/2892: CRL -> 152.76
# Fetched 686/2892: KNSL -> 100.5297
# Fetched 687/2892: FRT -> 100.7898
# Fetched 688/2892: PCOR -> None
# Fetched 689/2892: CAG -> 26.6311
# Fetched 690/2892: UGI -> 34.5194
# Fetched 691/2892: PRI -> 120.1055
# Fetched 692/2892: DINO -> 41.2579
# Fetched 693/2892: COKE -> 27.0595
# Fetched 694/2892: CUBE -> 24.6706
# Fetched 695/2892: DOX -> 63.3616
# Fetched 696/2892: SEIC -> 60.5012
# Fetched 697/2892: MOD -> 7.7
# Fetched 698/2892: LYFT -> 43.02
# Fetched 699/2892: FOX -> 33.403
# Fetched 700/2892: CNH -> 8.2486
# Fetched 701/2892: ATR -> 107.2805
# Fetched 702/2892: ADC -> 54.6204
# Fetched 703/2892: PAYC -> 259.4823
# Fetched 704/2892: OSK -> 85.8602
# Fetched 705/2892: COLB -> 28.009
# Fetched 706/2892: VMI -> 141.3001
# Fetched 707/2892: LAD -> 141.2603
# Fetched 708/2892: AWI -> 88.3895
# Fetched 709/2892: SFM -> 19.35
# Fetched 710/2892: NCLH -> 58.41
# Fetched 711/2892: AHR -> None
# Fetched 712/2892: CRBG -> None
# Fetched 713/2892: MTCH -> 80.2236
# Fetched 714/2892: RGTI -> None
# Fetched 715/2892: ROIV -> None
# Fetched 716/2892: MP -> None
# Fetched 717/2892: SN -> None
# Fetched 718/2892: HSIC -> 66.72
# Fetched 719/2892: RBRK -> None
# Fetched 720/2892: UMBF -> 61.8055
# Fetched 721/2892: SANM -> 34.24
# Fetched 722/2892: XP -> 34.3345
# Fetched 723/2892: BRX -> 16.422
# Fetched 724/2892: MOH -> 135.69
# Fetched 725/2892: LW -> 78.1575
# Fetched 726/2892: LKQ -> 32.0488
# Fetched 727/2892: CTRE -> 15.2372
# Fetched 728/2892: CYTK -> 10.61
# Fetched 729/2892: TAP -> 46.3791
# Fetched 730/2892: AVTR -> 18.15
# Fetched 731/2892: TPG -> None
# Fetched 732/2892: AEIS -> 69.8311
# Fetched 733/2892: NNN -> 39.0673
# Fetched 734/2892: AXS -> 49.7963
# Fetched 735/2892: MOS -> 19.257
# Fetched 736/2892: ZION -> 42.1787
# Fetched 737/2892: BPOP -> 48.7892
# Fetched 738/2892: LUMN -> 10.4505
# Fetched 739/2892: ALSN -> 43.7338
# Fetched 740/2892: ONB -> 15.0681
# Fetched 741/2892: OLLI -> 65.31
# Fetched 742/2892: HIMS -> 9.9
# Fetched 743/2892: AOS -> 42.4671
# Fetched 744/2892: SAIA -> 93.12
# Fetched 745/2892: CORT -> 12.1
# Fetched 746/2892: WTS -> 95.0817
# Fetched 747/2892: AMG -> 84.2713
# Fetched 748/2892: STAG -> 24.49
# Fetched 749/2892: CHWY -> 29
# Fetched 750/2892: ACI -> None
# Fetched 751/2892: CADE -> 23.8428
# Fetched 752/2892: NFG -> 37.9141
# Fetched 753/2892: CFR -> 81.53
# Fetched 754/2892: OMF -> 21.2706
# Fetched 755/2892: WING -> 78.201
# Fetched 756/2892: CLF -> 8.2083
# Fetched 757/2892: FR -> 35.4278
# Fetched 758/2892: JBTM -> 110.276
# Fetched 759/2892: QRVO -> 116.23
# Fetched 760/2892: RNA -> None
# Fetched 761/2892: CART -> None
# Fetched 762/2892: KNX -> 33.6655
# Fetched 763/2892: EXP -> 88.0419
# Fetched 764/2892: MGM -> 32.9983
# Fetched 765/2892: DUOL -> None
# Fetched 766/2892: CMC -> 20.2061
# Fetched 767/2892: G -> 39.0682
# Fetched 768/2892: IDA -> 89.2612
# Fetched 769/2892: LNC -> 44.2533
# Fetched 770/2892: ZWS -> 14.8945
# Fetched 771/2892: EMN -> 63.8986
# Fetched 772/2892: TTMI -> 15.05
# Fetched 773/2892: ONTO -> 36.54
# Fetched 774/2892: PNFP -> 59.8871
# Fetched 775/2892: SSD -> 76.3251
# Fetched 776/2892: BEN -> 19.3511
# Fetched 777/2892: JXN -> None
# Fetched 778/2892: MUSA -> 113.7275
# Fetched 779/2892: FLR -> 18.6899
# Fetched 780/2892: INGR -> 78.8849
# Fetched 781/2892: QBTS -> None
# Fetched 782/2892: R -> 45.0822
# Fetched 783/2892: TTC -> 72.815
# Fetched 784/2892: CHDN -> 67.2519
# Fetched 785/2892: BROS -> None
# Fetched 786/2892: AXTA -> 30.4
# Fetched 787/2892: DOCS -> None
# Fetched 788/2892: FSS -> 30.7726
# Fetched 789/2892: ORA -> 71.7999
# Fetched 790/2892: PRIM -> 21.1566
# Fetched 791/2892: AL -> 42.3368
# Fetched 792/2892: MAT -> 13.55
# Fetched 793/2892: VOYA -> 55.1232
# Fetched 794/2892: HRL -> 38.167
# Fetched 795/2892: FND -> 50.81
# Fetched 796/2892: CELH -> 1.61
# Fetched 797/2892: EAT -> 41.548
# Fetched 798/2892: CBSH -> 47.8429
# Fetched 799/2892: SNV -> 30.9243
# Fetched 800/2892: MTG -> 12.3109
# Fetched 801/2892: THG -> 118.6157
# Fetched 802/2892: PTCT -> 48.03
# Fetched 803/2892: H -> 88.4134
# Fetched 804/2892: AGCO -> 64.3835
# Fetched 805/2892: BSY -> None
# Fetched 806/2892: JOBY -> None
# Fetched 807/2892: PCTY -> 120.82
# Fetched 808/2892: VNO -> 52.0693
# Fetched 809/2892: MASI -> 158.06
# Fetched 810/2892: ESAB -> None
# Fetched 811/2892: SMTC -> 52.9
# Fetched 812/2892: TEM -> None
# Fetched 813/2892: ESTC -> 64.3
# Fetched 814/2892: FAF -> 47.4796
# Fetched 815/2892: TRNO -> 46.2233
# Fetched 816/2892: MOG/A -> None
# Fetched 817/2892: CGNX -> 52.7115
# Fetched 818/2892: ARWR -> 63.43
# Fetched 819/2892: STWD -> 13.7844
# Fetched 820/2892: KEX -> 89.53
# Fetched 821/2892: PB -> 59.1612
# Fetched 822/2892: AAON -> 31.9219
# Fetched 823/2892: CHE -> 430.8029
# Fetched 824/2892: LFUS -> 180.2645
# Fetched 825/2892: SITM -> 25.5
# Fetched 826/2892: FBIN -> 51.2835
# Fetched 827/2892: EXLS -> 13.892
# Fetched 828/2892: EPRT -> 19.0061
# Fetched 829/2892: FCFS -> 74.0128
# Fetched 830/2892: SEE -> 35.6151
# Fetched 831/2892: GAP -> 14.475
# Fetched 832/2892: IBP -> 63.4663
# Fetched 833/2892: RITM -> 9.3145
# Fetched 834/2892: SLM -> 7.9251
# Fetched 835/2892: CFLT -> None
# Fetched 836/2892: VNOM -> 17.2333
# Fetched 837/2892: VFC -> 82.0506
# Fetched 838/2892: M -> 13.7228
# Fetched 839/2892: CRUS -> 82.41
# Fetched 840/2892: MIR -> None
# Fetched 841/2892: RYAN -> None
# Fetched 842/2892: ESNT -> 46.3322
# Fetched 843/2892: BIO -> 370.03
# Fetched 844/2892: TMHC -> 21.86
# Fetched 845/2892: HXL -> 70.6335
# Fetched 846/2892: CWST -> 46.03
# Fetched 847/2892: AXSM -> 103.36
# Fetched 848/2892: AM -> 4.0761
# Fetched 849/2892: MSA -> 117.3324
# Fetched 850/2892: KD -> None
# Fetched 851/2892: MIDD -> 109.52
# Fetched 852/2892: FNB -> 10.0066
# Fetched 853/2892: HR -> 17.7139
# Fetched 854/2892: MKTX -> 357.1124
# Fetched 855/2892: MHK -> 136.38
# Fetched 856/2892: IRTC -> 68.09
# Fetched 857/2892: GKOS -> 54.47
# Fetched 858/2892: SITE -> 90.65
# Fetched 859/2892: BOOT -> 44.53
# Fetched 860/2892: BFAM -> 150.29
# Fetched 861/2892: ESI -> 10.8662
# Fetched 862/2892: AN -> 48.63
# Fetched 863/2892: RHP -> 73.468
# Fetched 864/2892: PIPR -> 66.5694
# Fetched 865/2892: KMX -> 87.67
# Fetched 866/2892: APLD -> None
# Fetched 867/2892: GTES -> 13.76
# Fetched 868/2892: DAR -> 28.08
# Fetched 869/2892: LEA -> 121.6967
# Fetched 870/2892: GXO -> None
# Fetched 871/2892: NOV -> 22.994
# Fetched 872/2892: TXNM -> 42.1519
# Fetched 873/2892: GATX -> 73.4967
# Fetched 874/2892: RDNT -> 20.3
# Fetched 875/2892: RYTM -> 22.96
# Fetched 876/2892: PCVX -> None
# Fetched 877/2892: COGT -> 2.8808
# Fetched 878/2892: HRB -> 18.6491
# Fetched 879/2892: BEPC -> None
# Fetched 880/2892: UFPI -> 44.6282
# Fetched 881/2892: ARW -> 84.74
# Fetched 882/2892: PATH -> None
# Fetched 883/2892: RIOT -> 1.12
# Fetched 884/2892: RAL -> None
# Fetched 885/2892: AS -> None
# Fetched 886/2892: DBX -> 17.91
# Fetched 887/2892: WH -> 56.8654
# Fetched 888/2892: GTLB -> None
# Fetched 889/2892: ESE -> 90.781
# Fetched 890/2892: POR -> 43.614
# Fetched 891/2892: CHRD -> None
# Fetched 892/2892: CVLT -> 44.64
# Fetched 893/2892: TIGO -> 42.3668
# Fetched 894/2892: VLY -> 8.7211
# Fetched 895/2892: JHG -> 17.6479
# Fetched 896/2892: NXST -> 97.8371
# Fetched 897/2892: BIPC -> None
# Fetched 898/2892: ENS -> 70.7125
# Fetched 899/2892: CIFR -> None
# Fetched 900/2892: WFRD -> 27.3281
# Fetched 901/2892: KRYS -> 55.38
# Fetched 902/2892: CWAN -> None
# Fetched 903/2892: THO -> 66.1166
# Fetched 904/2892: ETSY -> 44.3
# Fetched 905/2892: VNT -> None
# Fetched 906/2892: BKH -> 62.1202
# Fetched 907/2892: GBCI -> 37.9813
# Fetched 908/2892: SWX -> 61.7142
# Fetched 909/2892: KBR -> 28.4149
# Fetched 910/2892: HOMB -> 16.5561
# Fetched 911/2892: BMI -> 61.924
# Fetched 912/2892: WTM -> 1110.1148
# Fetched 913/2892: OLED -> 196.2547
# Fetched 914/2892: POST -> 71.3863
# Fetched 915/2892: CNX -> 8.85
# Fetched 916/2892: AGX -> 33.8955
# Fetched 917/2892: NUVL -> None
# Fetched 918/2892: UEC -> 0.9192
# Fetched 919/2892: UBSI -> 29.9526
# Fetched 920/2892: HWC -> 36.7814
# Fetched 921/2892: UHAL/B -> None
# Fetched 922/2892: LPX -> 27.2009
# Fetched 923/2892: PTGX -> 7.05
# Fetched 924/2892: GNTX -> 26.2169
# Fetched 925/2892: MTH -> 29.0561
# Fetched 926/2892: LBRDK -> 117.7173
# Fetched 927/2892: FCN -> 110.66
# Fetched 928/2892: TKR -> 50.5944
# Fetched 929/2892: QS -> None
# Fetched 930/2892: SR -> 64.8644
# Fetched 931/2892: BCPC -> 98.2035
# Fetched 932/2892: OPCH -> 14.92
# Fetched 933/2892: QLYS -> 83.37
# Fetched 934/2892: KRG -> 15.0554
# Fetched 935/2892: ROAD -> 16.87
# Fetched 936/2892: RLI -> 39.6593
# Fetched 937/2892: ACA -> 43.684
# Fetched 938/2892: TFX -> 362.509
# Fetched 939/2892: WEX -> 209.46
# Fetched 940/2892: KRC -> 62.5999
# Fetched 941/2892: APPF -> 109.95
# Fetched 942/2892: MTN -> 197.7457
# Fetched 943/2892: BRKR -> 49.9751
# Fetched 944/2892: OGS -> 76.5916
# Fetched 945/2892: MMSI -> 31.22
# Fetched 946/2892: MTDR -> 16.8369
# Fetched 947/2892: MORN -> 145.6575
# Fetched 948/2892: GPI -> 96.1197
# Fetched 949/2892: HLNE -> 53.5468
# Fetched 950/2892: ALK -> 67.368
# Fetched 951/2892: OZK -> 24.476
# Fetched 952/2892: ACIW -> 37.885
# Fetched 953/2892: ABCB -> 38.9331
# Fetched 954/2892: CAVA -> None
# Fetched 955/2892: COMP -> None
# Fetched 956/2892: SKY -> 31.7
# Fetched 957/2892: MMS -> 67.97
# Fetched 958/2892: SIGI -> 59.5213
# Fetched 959/2892: FOUR -> None
# Fetched 960/2892: NJR -> 35.6544
# Fetched 961/2892: ACHR -> None
# Fetched 962/2892: TGTX -> 11.1
# Fetched 963/2892: ALKS -> 20.4
# Fetched 964/2892: TMDX -> 19.01
# Fetched 965/2892: CZR -> 59.64
# Fetched 966/2892: RDN -> 20.8615
# Fetched 967/2892: CORZ -> None
# Fetched 968/2892: PEGA -> 39.401
# Fetched 969/2892: AUB -> 30.2151
# Fetched 970/2892: SSRM -> 18.3431
# Fetched 971/2892: BILL -> 38.05
# Fetched 972/2892: GPK -> 14.9897
# Fetched 973/2892: BYD -> 28.6653
# Fetched 974/2892: S -> None
# Fetched 975/2892: BCO -> 84.5632
# Fetched 976/2892: MC -> 22.5363
# Fetched 977/2892: GVA -> 25.4294
# Fetched 978/2892: CE -> 109.9811
# Fetched 979/2892: ECG -> None
# Fetched 980/2892: LAZ -> 29.5602
# Fetched 981/2892: NPO -> 62.6783
# Fetched 982/2892: ST -> 51.2759
# Fetched 983/2892: WK -> 42.05
# Fetched 984/2892: CROX -> 41.89
# Fetched 985/2892: SBRA -> 13.09
# Fetched 986/2892: ABG -> 111.79
# Fetched 987/2892: ANF -> 17.04
# Fetched 988/2892: AMTM -> None
# Fetched 989/2892: REZI -> 11.93
# Fetched 990/2892: NEU -> 428.7819
# Fetched 991/2892: URBN -> 27.77
# Fetched 992/2892: LSTR -> 100.7257
# Fetched 993/2892: CCC -> None
# Fetched 994/2892: DVA -> 75.03
# Fetched 995/2892: PECO -> None
# Fetched 996/2892: ITRI -> 83.95
# Fetched 997/2892: CVCO -> 195.38
# Fetched 998/2892: PSN -> 41.28
# Fetched 999/2892: PI -> 25.86
# Fetched 1000/2892: QTWO -> 81.08
# Fetched 1001/2892: ADMA -> 4
# Fetched 1002/2892: BDC -> 53.9877
# Fetched 1003/2892: AUR -> None
# Fetched 1004/2892: AX -> 30.28
# Fetched 1005/2892: LOPE -> 95.79
# Fetched 1006/2892: MAC -> 19.5926
# Fetched 1007/2892: SOUN -> None
# Fetched 1008/2892: CRSP -> 60.905
# Fetched 1009/2892: WULF -> 4.5609
# Fetched 1010/2892: MRP -> None
# Fetched 1011/2892: CSW -> 74.7696
# Fetched 1012/2892: MARA -> 0.88
# Fetched 1013/2892: FORM -> 25.97
# Fetched 1014/2892: STEP -> None
# Fetched 1015/2892: CUZ -> 31.5895
# Fetched 1016/2892: MUR -> 21.7565
# Fetched 1017/2892: ASB -> 17.2924
# Fetched 1018/2892: MDU -> 9.4536
# Fetched 1019/2892: EOSE -> None
# Fetched 1020/2892: HRI -> 45.2668
# Fetched 1021/2892: BC -> 53.4278
# Fetched 1022/2892: SPR -> 72.6247
# Fetched 1023/2892: LMND -> None
# Fetched 1024/2892: OSIS -> 100.74
# Fetched 1025/2892: BF/B -> None
# Fetched 1026/2892: MGY -> 11.4643
# Fetched 1027/2892: FFIN -> 31.3439
# Fetched 1028/2892: COMM -> 13.7859
# Fetched 1029/2892: HUT -> 3.92
# Fetched 1030/2892: RUN -> 13.81
# Fetched 1031/2892: KBH -> 31.3024
# Fetched 1032/2892: ADT -> 6.9313
# Fetched 1033/2892: NWE -> 54.7007
# Fetched 1034/2892: EBC -> None
# Fetched 1035/2892: AMKR -> 12.1115
# Fetched 1036/2892: VSEC -> 36.2418
# Fetched 1037/2892: ELF -> 16.13
# Fetched 1038/2892: KNF -> None
# Fetched 1039/2892: STNE -> 39.89
# Fetched 1040/2892: CNR -> 8.8572
# Fetched 1041/2892: ATMU -> None
# Fetched 1042/2892: CLSK -> 5.3157
# Fetched 1043/2892: SON -> 49.7549
# Fetched 1044/2892: SNEX -> 21.7022
# Fetched 1045/2892: AGO -> 43.7654
# Fetched 1046/2892: WHR -> 111.1761
# Fetched 1047/2892: BOX -> 16.78
# Fetched 1048/2892: DLB -> 63.286
# Fetched 1049/2892: SAIC -> 79.496
# Fetched 1050/2892: CWEN -> 14.7209
# Fetched 1051/2892: SKYW -> 64.297
# Fetched 1052/2892: AROC -> 7.0877
# Fetched 1053/2892: TCBI -> 56.77
# Fetched 1054/2892: KTB -> 34.3437
# Fetched 1055/2892: SIRI -> 60.0982
# Fetched 1056/2892: VKTX -> 8.02
# Fetched 1057/2892: SXT -> 57.8196
# Fetched 1058/2892: SLAB -> 115.98
# Fetched 1059/2892: CRNX -> 25.09
# Fetched 1060/2892: NOVT -> 88.44
# Fetched 1061/2892: LEU -> 6.88
# Fetched 1062/2892: SIG -> 20.2378
# Fetched 1063/2892: INDV -> 2.6
# Fetched 1064/2892: IRT -> 11.3591
# Fetched 1065/2892: PRMB -> 11.9118
# Fetched 1066/2892: HASI -> 24.1106
# Fetched 1067/2892: PVH -> 104.2149
# Fetched 1068/2892: PRAX -> None
# Fetched 1069/2892: FTDR -> 47.42
# Fetched 1070/2892: LNTH -> 20.51
# Fetched 1071/2892: HCC -> 18.7318
# Fetched 1072/2892: FELE -> 53.9862
# Fetched 1073/2892: VSAT -> 73.195
# Fetched 1074/2892: VVV -> 20.2715
# Fetched 1075/2892: WAY -> None
# Fetched 1076/2892: AVT -> 36.3409
# Fetched 1077/2892: TDS -> 20.7836
# Fetched 1078/2892: ALE -> 63.3953
# Fetched 1079/2892: MSM -> 55.7708
# Fetched 1080/2892: VIAV -> 15
# Fetched 1081/2892: CNO -> 15.832
# Fetched 1082/2892: LAUR -> 8.1929
# Fetched 1083/2892: HAE -> 114.9
# Fetched 1084/2892: BRBR -> 21.29
# Fetched 1085/2892: EPR -> 49.0161
# Fetched 1086/2892: PFSI -> 31.6091
# Fetched 1087/2892: PRM -> None
# Fetched 1088/2892: CWK -> 20.44
# Fetched 1089/2892: PJT -> 41.3739
# Fetched 1090/2892: NE -> None
# Fetched 1091/2892: LGND -> 65.0593
# Fetched 1092/2892: BTSG -> None
# Fetched 1093/2892: PLXS -> 76.94
# Fetched 1094/2892: AKRO -> 22.195
# Fetched 1095/2892: BHF -> 39.23
# Fetched 1096/2892: LLYVK -> None
# Fetched 1097/2892: LTH -> None
# Fetched 1098/2892: CRCL -> None
# Fetched 1099/2892: CALM -> 33.4869
# Fetched 1100/2892: TREX -> 44.94
# Fetched 1101/2892: UPST -> None
# Fetched 1102/2892: MWA -> 10.867
# Fetched 1103/2892: SKT -> 11.1018
# Fetched 1104/2892: MSGS -> 209.836
# Fetched 1105/2892: GLNG -> 12.9153
# Fetched 1106/2892: IESC -> 25.66
# Fetched 1107/2892: BBWI -> 9.9685
# Fetched 1108/2892: SARO -> None
# Fetched 1109/2892: UCB -> 24.2528
# Fetched 1110/2892: RIG -> 6.88
# Fetched 1111/2892: SHC -> None
# Fetched 1112/2892: GFS -> None
# Fetched 1113/2892: VCYT -> 27.92
# Fetched 1114/2892: NHI -> 56.5238
# Fetched 1115/2892: MRCY -> 69.11
# Fetched 1116/2892: SFBS -> 34.2237
# Fetched 1117/2892: EXPO -> 64.5654
# Fetched 1118/2892: ENPH -> 26.13
# Fetched 1119/2892: VRNS -> 25.9033
# Fetched 1120/2892: DORM -> 75.72
# Fetched 1121/2892: INSP -> 74.21
# Fetched 1122/2892: IBOC -> 36.4049
# Fetched 1123/2892: VAL -> None
# Fetched 1124/2892: GNW -> 4.4
# Fetched 1125/2892: MATX -> 37.1899
# Fetched 1126/2892: GPOR -> None
# Fetched 1127/2892: GHC -> 599.9906
# Fetched 1128/2892: MHO -> 39.35
# Fetched 1129/2892: PII -> 84.7881
# Fetched 1130/2892: ICUI -> 187.12
# Fetched 1131/2892: WSC -> 18.2824
# Fetched 1132/2892: SRRK -> 13.18
# Fetched 1133/2892: SLGN -> 28.4133
# Fetched 1134/2892: NVST -> 29.64
# Fetched 1135/2892: PATK -> 30.9171
# Fetched 1136/2892: CDP -> 22.5767
# Fetched 1137/2892: INDB -> 68.4726
# Fetched 1138/2892: RYN -> 23.206
# Fetched 1139/2892: LIVN -> 75.43
# Fetched 1140/2892: OSCR -> None
# Fetched 1141/2892: VRRM -> 13.99
# Fetched 1142/2892: GRAL -> None
# Fetched 1143/2892: MYRG -> 32.59
# Fetched 1144/2892: ZETA -> None
# Fetched 1145/2892: SHAK -> 59.57
# Fetched 1146/2892: YETI -> 34.78
# Fetched 1147/2892: KFY -> 38.4751
# Fetched 1148/2892: XENE -> 13.11
# Fetched 1149/2892: CDTX -> 76.8
# Fetched 1150/2892: AVA -> 36.5751
# Fetched 1151/2892: KYMR -> None
# Fetched 1152/2892: SLG -> 62.1502
# Fetched 1153/2892: CBT -> 41.1849
# Fetched 1154/2892: BTU -> 8.7712
# Fetched 1155/2892: MZTI -> 142.5585
# Fetched 1156/2892: CALX -> 8
# Fetched 1157/2892: ALGM -> None
# Fetched 1158/2892: HAYW -> None
# Fetched 1159/2892: BNL -> None
# Fetched 1160/2892: BKU -> 29.8481
# Fetched 1161/2892: RNST -> 30.0206
# Fetched 1162/2892: AEO -> 12.5814
# Fetched 1163/2892: FULT -> 13.4744
# Fetched 1164/2892: ATGE -> 34.97
# Fetched 1165/2892: CATY -> 30.9961
# Fetched 1166/2892: TENB -> 23.96
# Fetched 1167/2892: KAI -> 101.6889
# Fetched 1168/2892: PLMR -> 50.49
# Fetched 1169/2892: PSMT -> 65.3462
# Fetched 1170/2892: AGYS -> 25.41
# Fetched 1171/2892: OUT -> 19.6386
# Fetched 1172/2892: CRC -> None
# Fetched 1173/2892: ARQT -> None
# Fetched 1174/2892: CPK -> 85.456
# Fetched 1175/2892: PCH -> 31.3958
# Fetched 1176/2892: BXMT -> 20.1277
# Fetched 1177/2892: FUL -> 47.8024
# Fetched 1178/2892: TGNA -> 14.4515
# Fetched 1179/2892: SPSC -> 55.42
# Fetched 1180/2892: ASO -> None
# Fetched 1181/2892: FBP -> 8.7087
# Fetched 1182/2892: BGC -> 5.4878
# Fetched 1183/2892: EEFT -> 157.56
# Fetched 1184/2892: WGS -> None
# Fetched 1185/2892: FHB -> 22.0694
# Fetched 1186/2892: AZZ -> 42.2872
# Fetched 1187/2892: ACAD -> 42.78
# Fetched 1188/2892: BFH -> 63.8107
# Fetched 1189/2892: OTTR -> 43.6635
# Fetched 1190/2892: ENVA -> 24.06
# Fetched 1191/2892: AAP -> 142.0596
# Fetched 1192/2892: POWL -> 42.5776
# Fetched 1193/2892: AWR -> 77.0719
# Fetched 1194/2892: TVTX -> 14.2
# Fetched 1195/2892: RARE -> 42.71
# Fetched 1196/2892: TPC -> 12.8488
# Fetched 1197/2892: COLD -> 28.5225
# Fetched 1198/2892: TARS -> None
# Fetched 1199/2892: MGEE -> 69.2804
# Fetched 1200/2892: WSFS -> 40.697
# Fetched 1201/2892: GSAT -> 7.8
# Fetched 1202/2892: UUUU -> 1.91
# Fetched 1203/2892: WSBC -> 28.7804
# Fetched 1204/2892: DOCN -> None
# Fetched 1205/2892: NG -> 8.96
# Fetched 1206/2892: AIR -> 44.8557
# Fetched 1207/2892: SHOO -> 38.3473
# Fetched 1208/2892: CBU -> 59.1254
# Fetched 1209/2892: AMBA -> 60.56
# Fetched 1210/2892: CPRI -> 38.15
# Fetched 1211/2892: TPH -> 15.58
# Fetched 1212/2892: PBH -> 40.5
# Fetched 1213/2892: DAN -> 15.905
# Fetched 1214/2892: CELC -> 10.64
# Fetched 1215/2892: PAG -> 44.056
# Fetched 1216/2892: SXI -> 74.851
# Fetched 1217/2892: HIW -> 33.3505
# Fetched 1218/2892: TEX -> 27.8108
# Fetched 1219/2892: YOU -> None
# Fetched 1220/2892: SFNC -> 21.3543
# Fetched 1221/2892: GFF -> 16.4631
# Fetched 1222/2892: JHX -> 18.796
# Fetched 1223/2892: GTM -> None
# Fetched 1224/2892: NMIH -> 33.18
# Fetched 1225/2892: LOAR -> None
# Fetched 1226/2892: BL -> 51.56
# Fetched 1227/2892: FIBK -> 29.8772
# Fetched 1228/2892: WU -> 17.829
# Fetched 1229/2892: ADPT -> 29.92
# Fetched 1230/2892: MIRM -> 24.52
# Fetched 1231/2892: CARG -> 35.18
# Fetched 1232/2892: TBBK -> 12.97
# Fetched 1233/2892: BCC -> 26.1599
# Fetched 1234/2892: VC -> 86.1565
# Fetched 1235/2892: VIRT -> 12.6805
# Fetched 1236/2892: CNK -> 32.946
# Fetched 1237/2892: GLOB -> 106.05
# Fetched 1238/2892: PBF -> 28.223
# Fetched 1239/2892: IDYA -> 7.5
# Fetched 1240/2892: LBRT -> 10.4391
# Fetched 1241/2892: AVNT -> 31.5941
# Fetched 1242/2892: MPW -> 13.2716
# Fetched 1243/2892: RRR -> 19.2975
# Fetched 1244/2892: VSCO -> None
# Fetched 1245/2892: LXP -> 40.1091
# Fetched 1246/2892: VCTR -> 17.8091
# Fetched 1247/2892: CXT -> 27.2105
# Fetched 1248/2892: HURN -> 68.72
# Fetched 1249/2892: ALHC -> None
# Fetched 1250/2892: LCII -> 87.2972
# Fetched 1251/2892: FRPT -> 59.09
# Fetched 1252/2892: PRVA -> None
# Fetched 1253/2892: HHH -> 114.8934
# Fetched 1254/2892: PL -> None
# Fetched 1255/2892: TDC -> 26.77
# Fetched 1256/2892: HOG -> 33.2219
# Fetched 1257/2892: CPRX -> 3.75
# Fetched 1258/2892: RHI -> 52.9875
# Fetched 1259/2892: KAR -> 21.4984
# Fetched 1260/2892: CIVI -> 15.982
# Fetched 1261/2892: LRN -> 20.35
# Fetched 1262/2892: FOLD -> 9.74
# Fetched 1263/2892: ATEC -> 7.095
# Fetched 1264/2892: HP -> 33.9372
# Fetched 1265/2892: NMRK -> 12.613
# Fetched 1266/2892: NATL -> None
# Fetched 1267/2892: AKR -> 20.7501
# Fetched 1268/2892: SBCF -> 27.2257
# Fetched 1269/2892: CWT -> 45.856
# Fetched 1270/2892: ABM -> 33.6314
# Fetched 1271/2892: APLE -> 12.304
# Fetched 1272/2892: NCNO -> None
# Fetched 1273/2892: WDFC -> 177.2896
# Fetched 1274/2892: KSS -> 36.2727
# Fetched 1275/2892: ACLS -> 24.095
# Fetched 1276/2892: KGS -> None
# Fetched 1277/2892: SYNA -> 65.77
# Fetched 1278/2892: APAM -> 19.558
# Fetched 1279/2892: UNF -> 194.252
# Fetched 1280/2892: TDW -> 19.2581
# Fetched 1281/2892: DRS -> 5.1388
# Fetched 1282/2892: CVBF -> 16.8614
# Fetched 1283/2892: PRK -> 82.0816
# Fetched 1284/2892: MGRC -> 67.557
# Fetched 1285/2892: DNLI -> 17.42
# Fetched 1286/2892: REVG -> 9.6649
# Fetched 1287/2892: BOH -> 73.9992
# Fetched 1288/2892: PTON -> 28.4
# Fetched 1289/2892: CHH -> 98.807
# Fetched 1290/2892: PFS -> 18.1377
# Fetched 1291/2892: DNOW -> 11.24
# Fetched 1292/2892: XMTR -> None
# Fetched 1293/2892: SMG -> 87.7685
# Fetched 1294/2892: SMR -> None
# Fetched 1295/2892: BKD -> 7.27
# Fetched 1296/2892: STNG -> 33.9789
# Fetched 1297/2892: LINE -> None
# Fetched 1298/2892: HWKN -> 21.3008
# Fetched 1299/2892: NSIT -> 70.29
# Fetched 1300/2892: MCY -> 38.8372
# Fetched 1301/2892: WAFD -> 30.1204
# Fetched 1302/2892: ASH -> 68.8828
# Fetched 1303/2892: BOKF -> 75.2085
# Fetched 1304/2892: UI -> 178.3981
# Fetched 1305/2892: CGON -> None
# Fetched 1306/2892: MTRN -> 57.3874
# Fetched 1307/2892: KMPR -> 68.0648
# Fetched 1308/2892: TOWN -> 22.8434
# Fetched 1309/2892: SUPN -> 23.72
# Fetched 1310/2892: ACLX -> None
# Fetched 1311/2892: FFBC -> 19.7041
# Fetched 1312/2892: ITGR -> 80.43
# Fetched 1313/2892: HGV -> 34.39
# Fetched 1314/2892: ALRM -> 42.97
# Fetched 1315/2892: CBZ -> 26.96
# Fetched 1316/2892: LEN/B -> None
# Fetched 1317/2892: APGE -> None
# Fetched 1318/2892: OLN -> 14.7359
# Fetched 1319/2892: INTA -> None
# Fetched 1320/2892: RH -> 213.5
# Fetched 1321/2892: UE -> 15.0978
# Fetched 1322/2892: RUSHA -> 18.9002
# Fetched 1323/2892: FRSH -> None
# Fetched 1324/2892: CON -> None
# Fetched 1325/2892: CSTM -> 13.4
# Fetched 1326/2892: BEAM -> None
# Fetched 1327/2892: UPWK -> 10.67
# Fetched 1328/2892: BIRK -> None
# Fetched 1329/2892: IAC -> 44.5204
# Fetched 1330/2892: PLUS -> 41.8839
# Fetched 1331/2892: CURB -> None
# Fetched 1332/2892: FCPT -> 20.3937
# Fetched 1333/2892: BANR -> 45.9097
# Fetched 1334/2892: DYN -> None
# Fetched 1335/2892: DXC -> 36.8618
# Fetched 1336/2892: CAR -> 30.6315
# Fetched 1337/2892: APLS -> 30.62
# Fetched 1338/2892: BANC -> 15.0584
# Fetched 1339/2892: FRHC -> 14.54
# Fetched 1340/2892: KLIC -> 24.6152
# Fetched 1341/2892: JOE -> 18.9004
# Fetched 1342/2892: EXTR -> 7.37
# Fetched 1343/2892: BANF -> 55.1708
# Fetched 1344/2892: FBK -> 36.3219
# Fetched 1345/2892: COCO -> None
# Fetched 1346/2892: SPHR -> None
# Fetched 1347/2892: BRZE -> None
# Fetched 1348/2892: OII -> 14.91
# Fetched 1349/2892: GOLF -> 29.6331
# Fetched 1350/2892: RNG -> 168.67
# Fetched 1351/2892: DK -> 27.2629
# Fetched 1352/2892: PARR -> 23.24
# Fetched 1353/2892: XRAY -> 50.2066
# Fetched 1354/2892: WLK -> 63.6239
# Fetched 1355/2892: CHEF -> 38.11
# Fetched 1356/2892: HUBG -> 25.0209
# Fetched 1357/2892: ATKR -> 39.2213
# Fetched 1358/2892: HI -> 28.582
# Fetched 1359/2892: RELY -> None
# Fetched 1360/2892: PENN -> 25.56
# Fetched 1361/2892: IVT -> 12.426
# Fetched 1362/2892: GT -> 15.3713
# Fetched 1363/2892: TRMK -> 28.6317
# Fetched 1364/2892: EYE -> 32.43
# Fetched 1365/2892: GENI -> None
# Fetched 1366/2892: GTX -> 9.7772
# Fetched 1367/2892: UNFI -> 8.76
# Fetched 1368/2892: VRDN -> 7.1985
# Fetched 1369/2892: ADUS -> 97.22
# Fetched 1370/2892: IRON -> None
# Fetched 1371/2892: OCUL -> 3.95
# Fetched 1372/2892: CAKE -> 34.597
# Fetched 1373/2892: PLUG -> 3.16
# Fetched 1374/2892: CSGS -> 45.5945
# Fetched 1375/2892: SM -> 10.2383
# Fetched 1376/2892: WD -> 55.1384
# Fetched 1377/2892: NOG -> 19.2225
# Fetched 1378/2892: NBTB -> 33.5211
# Fetched 1379/2892: BLKB -> 79.4689
# Fetched 1380/2892: VICR -> 46.72
# Fetched 1381/2892: GEO -> 14.1356
# Fetched 1382/2892: SONO -> 15.62
# Fetched 1383/2892: TRN -> 17.6658
# Fetched 1384/2892: FRME -> 33.7453
# Fetched 1385/2892: CRVL -> 29.12
# Fetched 1386/2892: PK -> 17.274
# Fetched 1387/2892: TERN -> None
# Fetched 1388/2892: RXO -> None
# Fetched 1389/2892: SMMT -> 1.6
# Fetched 1390/2892: DIOD -> 56.37
# Fetched 1391/2892: INSW -> 18.5606
# Fetched 1392/2892: GRBK -> 11.48
# Fetched 1393/2892: PTEN -> 8.9887
# Fetched 1394/2892: SLNO -> 44.1
# Fetched 1395/2892: STC -> 33.8145
# Fetched 1396/2892: SPNT -> 9.9887
# Fetched 1397/2892: ZG -> 45.74
# Fetched 1398/2892: ARR -> 35.9752
# Fetched 1399/2892: EPAC -> 25.7891
# Fetched 1400/2892: PHIN -> None
# Fetched 1401/2892: MGNI -> 8.16
# Fetched 1402/2892: MD -> 27.79
# Fetched 1403/2892: CACC -> 442.33
# Fetched 1404/2892: KMT -> 30.9266
# Fetched 1405/2892: MSGE -> None
# Fetched 1406/2892: NSA -> 24.8729
# Fetched 1407/2892: HE -> 40.5543
# Fetched 1408/2892: OI -> 11.8807
# Fetched 1409/2892: DAVE -> None
# Fetched 1410/2892: LQDA -> 4.275
# Fetched 1411/2892: LC -> 12.62
# Fetched 1412/2892: BUSE -> 21.4201
# Fetched 1413/2892: OGN -> None
# Fetched 1414/2892: NWN -> 57.2949
# Fetched 1415/2892: FBNC -> 34.642
# Fetched 1416/2892: EFSC -> 42.419
# Fetched 1417/2892: FLO -> 16.9562
# Fetched 1418/2892: IPGP -> 144.92
# Fetched 1419/2892: GEF -> 35.804
# Fetched 1420/2892: VCEL -> 17.4
# Fetched 1421/2892: CUBI -> 23.81
# Fetched 1422/2892: BKE -> 14.7204
# Fetched 1423/2892: KN -> 21.15
# Fetched 1424/2892: CRK -> 7.8018
# Fetched 1425/2892: DEI -> 33.0246
# Fetched 1426/2892: TXG -> 76.25
# Fetched 1427/2892: OSW -> 16.3598
# Fetched 1428/2892: DDS -> 56.0379
# Fetched 1429/2892: ASGN -> 70.97
# Fetched 1430/2892: SRPT -> 129.04
# Fetched 1431/2892: NUVB -> None
# Fetched 1432/2892: LBTYA -> 11.7143
# Fetched 1433/2892: HNI -> 30.49
# Fetched 1434/2892: CXW -> 16.3141
# Fetched 1435/2892: PGNY -> 27.45
# Fetched 1436/2892: BWIN -> 16.05
# Fetched 1437/2892: TWST -> 21
# Fetched 1438/2892: SDRL -> None
# Fetched 1439/2892: NTB -> 26.7159
# Fetched 1440/2892: WRBY -> None
# Fetched 1441/2892: POWI -> 46.4958
# Fetched 1442/2892: BUR -> 8.8218
# Fetched 1443/2892: PPTA -> 4.855
# Fetched 1444/2892: PAGS -> 32.7245
# Fetched 1445/2892: AVDL -> 7.55
# Fetched 1446/2892: NGVT -> 87.38
# Fetched 1447/2892: KWR -> 154.5617
# Fetched 1448/2892: HMN -> 35.4449
# Fetched 1449/2892: CC -> 14.2447
# Fetched 1450/2892: EVTC -> 32.9186
# Fetched 1451/2892: MQ -> None
# Fetched 1452/2892: AMRX -> 4.82
# Fetched 1453/2892: BELFB -> 19.0418
# Fetched 1454/2892: DJT -> None
# Fetched 1455/2892: SMPL -> 28.54
# Fetched 1456/2892: BBAI -> None
# Fetched 1457/2892: NTCT -> 24.07
# Fetched 1458/2892: MRX -> None
# Fetched 1459/2892: DRH -> 9.9714
# Fetched 1460/2892: MTX -> 56.1123
# Fetched 1461/2892: AUPH -> 20.26
# Fetched 1462/2892: PRGO -> 42.4619
# Fetched 1463/2892: QDEL -> 75.03
# ...
# Fetched 2445/2892: PLTK -> 4.4816
# Fetched 2446/2892: DSGR -> 27.47
# Fetched 2447/2892: HYLN -> 1.32
# Fetched 2448/2892: MGPI -> 29.7049
# Fetched 2449/2892: GRNT -> 6.1143
# Fetched 2450/2892: TRDA -> 6.72
# Fetched 2451/2892: SVC -> 2.3708
# Fetched 2452/2892: ABL -> 4.9868
# Fetched 2453/2892: PDLB -> 13.84
# Fetched 2454/2892: MEC -> 15.96
# Fetched 2455/2892: NNOX -> 5.17
# Fetched 2456/2892: BOC -> 14.04
# Fetched 2457/2892: OOMA -> 12.9
# Fetched 2458/2892: CNDT -> 2.64
# Fetched 2459/2892: VNDA -> 4.72
# Fetched 2460/2892: MEI -> 9.3435
# Fetched 2461/2892: SMLR -> 38.74
# Fetched 2462/2892: GBFH -> 35.41
# Fetched 2463/2892: FDBC -> 45.1293
# Fetched 2464/2892: BIOA -> 4.13
# Fetched 2465/2892: JMSB -> 18.53
# Fetched 2466/2892: HNST -> 5.09
# Fetched 2467/2892: AVNW -> 24.05
# Fetched 2468/2892: KELYA -> 11.545
# Fetched 2469/2892: AMCX -> 6.27
# Fetched 2470/2892: ENTA -> 7.56
# Fetched 2471/2892: FRST -> 10.6517
# Fetched 2472/2892: NWFL -> 25.1587
# Fetched 2473/2892: CRML -> 3.58
# Fetched 2474/2892: WBTN -> 9.08
# Fetched 2475/2892: KFS -> 13.54
# Fetched 2476/2892: BETR -> 12.39
# Fetched 2477/2892: DHIL -> 139.3144
# Fetched 2478/2892: BLZE -> 5.5
# Fetched 2479/2892: KRMD -> 3.58
# Fetched 2480/2892: DDD -> 1.54
# Fetched 2481/2892: HSHP -> 5.4532
# Fetched 2482/2892: RCKT -> 2.45
# Fetched 2483/2892: LE -> 10.71
# Fetched 2484/2892: TBRG -> 23.42
# Fetched 2485/2892: QTRX -> 6.65
# Fetched 2486/2892: SSP -> 2.94
# Fetched 2487/2892: SIGA -> 6.52
# Fetched 2488/2892: XPER -> 7.91
# Fetched 2489/2892: CBAN -> 16.2364
# Fetched 2490/2892: XOMA -> 25.2
# Fetched 2491/2892: SKYH -> 9.77
# Fetched 2492/2892: JCAP -> 18.0109
# Fetched 2493/2892: PKOH -> 17.6141
# Fetched 2494/2892: PCYO -> 10.72
# Fetched 2495/2892: RCKY -> 21.9627
# Fetched 2496/2892: TBCH -> 13.83
# Fetched 2497/2892: CRCT -> 5.9719
# Fetched 2498/2892: ACRS -> 1.42
# Fetched 2499/2892: FTK -> 14.76
# Fetched 2500/2892: HBT -> 24.7804
# Fetched 2501/2892: AVIR -> 3.6
# Fetched 2502/2892: EDIT -> 2.2
# Fetched 2503/2892: FBLA -> 11.25
# Fetched 2504/2892: REFI -> 12.9622
# Fetched 2505/2892: LCNB -> 14.124
# Fetched 2506/2892: QSI -> 1.96
# Fetched 2507/2892: LOCO -> 11.01
# Fetched 2508/2892: CMRC -> 5
# Fetched 2509/2892: ATEX -> 25.65
# Fetched 2510/2892: RR -> 1.95
# Fetched 2511/2892: PSFE -> 12.62
# Fetched 2512/2892: PINE -> 14.2018
# Fetched 2513/2892: ASLE -> 6.01
# Fetched 2514/2892: ASUR -> 9.76
# Fetched 2515/2892: WEYS -> 32.5994
# Fetched 2516/2892: MITT -> 7.1489
# Fetched 2517/2892: ISTR -> 19.1492
# Fetched 2518/2892: ONIT -> 38.17
# Fetched 2519/2892: NC -> 43.7956
# Fetched 2520/2892: SMC -> 24.53
# Fetched 2521/2892: LDI -> 1.27
# Fetched 2522/2892: LXEO -> 4.02
# Fetched 2523/2892: WOW -> 4.06
# Fetched 2524/2892: FRPH -> 26.89
# Fetched 2525/2892: CADL -> 5.06
# Fetched 2526/2892: MYFW -> 22.56
# Fetched 2527/2892: BH -> 292.21
# Fetched 2528/2892: FRAF -> 34.3457
# Fetched 2529/2892: THRY -> 12.16
# Fetched 2530/2892: BMBL -> 6.59
# Fetched 2531/2892: BALY -> 9.58
# Fetched 2532/2892: LOVE -> 18.2
# Fetched 2533/2892: OMI -> 9.1
# Fetched 2534/2892: SLQT -> 2.38
# Fetched 2535/2892: III -> 4.7221
# Fetched 2536/2892: RBBN -> 4.01
# Fetched 2537/2892: FUNC -> 30.5764
# Fetched 2538/2892: FVCB -> 11.6918
# Fetched 2539/2892: CHMG -> 47.8855
# Fetched 2540/2892: FSBW -> 38.8702
# Fetched 2541/2892: BLFY -> 9.57
# Fetched 2542/2892: WSBF -> 13.528
# Fetched 2543/2892: FSTR -> 21.87
# Fetched 2544/2892: TH -> 7.12
# Fetched 2545/2892: JELD -> 3.92
# Fetched 2546/2892: SKYX -> 1.045
# Fetched 2547/2892: WNEB -> 9.1176
# Fetched 2548/2892: FENC -> 8.3
# Fetched 2549/2892: ATLO -> 17.4696
# Fetched 2550/2892: EVEX -> 6.86
# Fetched 2551/2892: ABEO -> 5.68
# Fetched 2552/2892: PLSE -> 15.09
# Fetched 2553/2892: FCCO -> 24.0778
# Fetched 2554/2892: NRC -> 16.5128
# Fetched 2555/2892: PACK -> 3.57
# Fetched 2556/2892: TG -> 8.8
# Fetched 2557/2892: JOUT -> 29.7311
# Fetched 2558/2892: LPRO -> 1.94
# Fetched 2559/2892: PESI -> 10.52
# Fetched 2560/2892: SLS -> 2.19
# Fetched 2561/2892: DOUG -> 2.32
# Fetched 2562/2892: ARDT -> 13.66
# Fetched 2563/2892: ASPN -> 5.92
# Fetched 2564/2892: RMR -> 15.4533
# Fetched 2565/2892: LEGH -> 22.66
# Fetched 2566/2892: USAU -> 12.2
# Fetched 2567/2892: UIS -> 4.53
# Fetched 2568/2892: CAPR -> 9.93
# Fetched 2569/2892: BNTC -> 11.7
# Fetched 2570/2892: ALCO -> 32.6312
# Fetched 2571/2892: XPOF -> 7.49
# Fetched 2572/2892: USNA -> 30.53
# Fetched 2573/2892: MBCN -> 29.7257
# Fetched 2574/2892: ONTF -> 5.43
# Fetched 2575/2892: CZFS -> 57.795
# Fetched 2576/2892: TLSI -> 5.45
# Fetched 2577/2892: OLPX -> 1.4
# Fetched 2578/2892: PANL -> 4.6216
# Fetched 2579/2892: ATNI -> 15.7682
# Fetched 2580/2892: VABK -> 36.339
# Fetched 2581/2892: HWBK -> 28.7878
# Fetched 2582/2892: PAL -> 7.26
# Fetched 2583/2892: NGNE -> 14.95
# Fetched 2584/2892: OVLY -> 26.9458
# Fetched 2585/2892: LFCR -> 8.12
# Fetched 2586/2892: VOXR -> 3.1427
# Fetched 2587/2892: HLLY -> 2
# Fetched 2588/2892: PBYI -> 3.43
# Fetched 2589/2892: MG -> 8.01
# Fetched 2590/2892: RMNI -> 3.77
# Fetched 2591/2892: NFE -> 3.32
# Fetched 2592/2892: FXNC -> 19.2067
# Fetched 2593/2892: CFFI -> 60.9409
# Fetched 2594/2892: PCB -> 20.5848
# Fetched 2595/2892: NKSH -> 26.501
# Fetched 2596/2892: OPRT -> 7.16
# Fetched 2597/2892: ARCT -> 13.01
# Fetched 2598/2892: USCB -> 16.3531
# Fetched 2599/2892: VMD -> 6.91
# Fetched 2600/2892: HRTX -> 2.07
# Fetched 2601/2892: RGCO -> 21.9518
# Fetched 2602/2892: FEIM -> 22.71
# Fetched 2603/2892: ALLO -> 1.13
# Fetched 2604/2892: HCAT -> 3.77
# Fetched 2605/2892: MFIN -> 9.3061
# Fetched 2606/2892: VYGR -> 3.11
# Fetched 2607/2892: CTGO -> 19.48
# Fetched 2608/2892: NPB -> 13.6678
# Fetched 2609/2892: INR -> 18.31
# Fetched 2610/2892: VEL -> 18.54
# Fetched 2611/2892: RLGT -> 6.08
# Fetched 2612/2892: JRVR -> 5.8403
# Fetched 2613/2892: PAYS -> 7.2
# Fetched 2614/2892: TCX -> 19.71
# Fetched 2615/2892: CMDB -> 8.67
# Fetched 2616/2892: EGAN -> 6.25
# Fetched 2617/2892: JAKK -> 20.1894
# Fetched 2618/2892: SKIN -> 1.91
# Fetched 2619/2892: BZAI -> 2.98
# Fetched 2620/2892: CRMT -> 56.04
# Fetched 2621/2892: FSFG -> 24.7712
# Fetched 2622/2892: CRD/A -> None
# Fetched 2623/2892: EFSI -> 30.0728
# Fetched 2624/2892: TSSI -> 28.83
# Fetched 2625/2892: ELMD -> 21.99
# Fetched 2626/2892: MASS -> 7.13
# Fetched 2627/2892: IMMR -> 7.7806
# Fetched 2628/2892: INSE -> 8.17
# Fetched 2629/2892: KRT -> 27.0804
# Fetched 2630/2892: AGL -> 2.3
# Fetched 2631/2892: VUZI -> 2.92
# Fetched 2632/2892: MXCT -> 2.18
# Fetched 2633/2892: CZWI -> 13.8
# Fetched 2634/2892: RSVR -> 7.67
# Fetched 2635/2892: EB -> 2.63
# Fetched 2636/2892: LNKB -> 7.1648
# Fetched 2637/2892: EVC -> 2.2393
# Fetched 2638/2892: CTRN -> 33.39
# Fetched 2639/2892: LVWR -> 4.6
# Fetched 2640/2892: STXS -> 2.12
# Fetched 2641/2892: AII -> 18.39
# Fetched 2642/2892: HUMA -> 2.09
# Fetched 2643/2892: OMDA -> 18.3
# Fetched 2644/2892: FLXS -> 35.7053
# Fetched 2645/2892: BRCC -> 1.31
# Fetched 2646/2892: FC -> 22.82
# Fetched 2647/2892: TRUE -> 1.9
# Fetched 2648/2892: KLTR -> 2.01
# Fetched 2649/2892: ALTI -> 4.15
# Fetched 2650/2892: BVFL -> 15.23
# Fetched 2651/2892: CBFV -> 28.0529
# Fetched 2652/2892: BKTI -> 47.13
# Fetched 2653/2892: UTMD -> 56.3368
# Fetched 2654/2892: FCAP -> 40.7852
# Fetched 2655/2892: FINW -> 15.01
# Fetched 2656/2892: GCBC -> 22.0292
# Fetched 2657/2892: POWW -> 1.28
# Fetched 2658/2892: LAW -> 4.37
# Fetched 2659/2892: TOI -> 2.05
# Fetched 2660/2892: PKBK -> 20.0259
# Fetched 2661/2892: OSUR -> 3
# Fetched 2662/2892: TTGT -> 7.77
# Fetched 2663/2892: TTSH -> 6.36
# Fetched 2664/2892: OPBK -> 12.7534
# Fetched 2665/2892: SNDA -> 24.95
# Fetched 2666/2892: MPAA -> 11.2
# Fetched 2667/2892: OABI -> 1.74
# Fetched 2668/2892: PDYN -> 8.66
# Fetched 2669/2892: RICK -> 37.9454
# Fetched 2670/2892: ASIC -> 21.52
# Fetched 2671/2892: SEG -> 18.65
# Fetched 2672/2892: FNWD -> 27.43
# Fetched 2673/2892: KGEI -> 6.85
# Fetched 2674/2892: RGP -> 5.2158
# Fetched 2675/2892: BHR -> 2.3648
# Fetched 2676/2892: CVRX -> 5.88
# Fetched 2677/2892: CDXS -> 2.44
# Fetched 2678/2892: BRT -> 15.1404
# Fetched 2679/2892: WEST -> 5.73
# Fetched 2680/2892: LRMR -> 2.89
# Fetched 2681/2892: BNED -> 11.77
# Fetched 2682/2892: BSVN -> 41.3426
# Fetched 2683/2892: MRBK -> 12.6693
# Fetched 2684/2892: INGN -> 7.03
# Fetched 2685/2892: ACTG -> 3.58
# Fetched 2686/2892: OVBC -> 31.8084
# Fetched 2687/2892: DERM -> 7.18
# Fetched 2688/2892: STRS -> 18.88
# Fetched 2689/2892: TRAK -> 19.5943
# Fetched 2690/2892: SMHI -> 5.1
# Fetched 2691/2892: STRZ -> 16.07
# Fetched 2692/2892: GETY -> 1.66
# Fetched 2693/2892: GENC -> 14
# Fetched 2694/2892: ACNT -> 12.61
# Fetched 2695/2892: PRTH -> 7.78
# Fetched 2696/2892: LWAY -> 24.65
# Fetched 2697/2892: SMID -> 33.56
# Fetched 2698/2892: PEBK -> 28.4881
# Fetched 2699/2892: PDEX -> 43.64
# Fetched 2700/2892: LAKE -> 13.5569
# Fetched 2701/2892: MDWD -> 19.37
# Fetched 2702/2892: MPTI -> 42
# Fetched 2703/2892: ZVIA -> 3.22
# Fetched 2704/2892: LARK -> 24.7803
# Fetched 2705/2892: RVSB -> 5.46
# Fetched 2706/2892: RMAX -> 8.18
# Fetched 2707/2892: UBFO -> 8.3282
# Fetched 2708/2892: INBK -> 26.7512
# Fetched 2709/2892: MNSB -> 18.7005
# Fetched 2710/2892: STRW -> 10.288
# Fetched 2711/2892: DBI -> 2.3218
# Fetched 2712/2892: MDV -> 13.5262
# Fetched 2713/2892: DSP -> 13.23
# Fetched 2714/2892: BFIN -> 11.3706
# Fetched 2715/2892: SNFCA -> 9.381
# Fetched 2716/2892: NREF -> 12.895
# Fetched 2717/2892: FHTX -> 4.7
# Fetched 2718/2892: FTLF -> 13.02
# Fetched 2719/2892: AVR -> 3.79
# Fetched 2720/2892: INSG -> 8.24
# Fetched 2721/2892: ANIK -> 10.58
# Fetched 2722/2892: ONEW -> 13.39
# Fetched 2723/2892: UHAL -> 60.56
# Fetched 2724/2892: SRBK -> 13.4112
# Fetched 2725/2892: CXDO -> 6.07
# Fetched 2726/2892: LUCD -> 1.15
# Fetched 2727/2892: SBFG -> 18.8281
# Fetched 2728/2892: CSPI -> 12.879
# Fetched 2729/2892: EHTH -> 4.35
# Fetched 2730/2892: BCBP -> 8.0917
# Fetched 2731/2892: ACR -> 17.94
# Fetched 2732/2892: LZM -> 4.12
# Fetched 2733/2892: EBMT -> 16.3823
# Fetched 2734/2892: NVCT -> 7.47
# Fetched 2735/2892: HNVR -> 22.6789
# Fetched 2736/2892: CBNA -> 25.77
# Fetched 2737/2892: PNBK -> 1.52
# Fetched 2738/2892: CURI -> 5.4383
# Fetched 2739/2892: EPM -> 4.4588
# Fetched 2740/2892: FRD -> 16.4842
# Fetched 2741/2892: PBFS -> 12.03
# Fetched 2742/2892: WHG -> 15.328
# Fetched 2743/2892: SEVN -> 11.4685
# Fetched 2744/2892: WTI -> 1.6319
# Fetched 2745/2892: RPT -> 15.4578
# Fetched 2746/2892: PLX -> 1.48
# Fetched 2747/2892: SFBC -> 45.6166
# Fetched 2748/2892: ULH -> 25.1024
# Fetched 2749/2892: RMBI -> 13.5139
# Fetched 2750/2892: CHRS -> 0.731
# Fetched 2751/2892: IKT -> 1.95
# Fetched 2752/2892: KINS -> 15.3071
# Fetched 2753/2892: BSET -> 14.8135
# Fetched 2754/2892: HBB -> 17.6144
# Fetched 2755/2892: QUAD -> 5.5068
# Fetched 2756/2892: FOA -> 23.32
# Fetched 2757/2892: ACU -> 41.1349
# Fetched 2758/2892: CFBK -> 23.8108
# Fetched 2759/2892: INNV -> 3.69
# Fetched 2760/2892: LFMD -> 13.62
# Fetched 2761/2892: TBI -> 6.48
# Fetched 2762/2892: TTEC -> 4.81
# Fetched 2763/2892: MPX -> 8.2334
# Fetched 2764/2892: BOOM -> 8.06
# Fetched 2765/2892: CLAR -> 3.4195
# Fetched 2766/2892: FATE -> 1.12
# Fetched 2767/2892: CATX -> 3.44
# Fetched 2768/2892: BPRN -> 29.924
# Fetched 2769/2892: DMRC -> 13.21
# Fetched 2770/2892: BBCP -> 6.15
# Fetched 2771/2892: SAMG -> 15.4433
# Fetched 2772/2892: AVD -> 3.92
# Fetched 2773/2892: EVCM -> 10.5
# Fetched 2774/2892: PMTS -> 23.72
# Fetched 2775/2892: CRDF -> 3.15
# Fetched 2776/2892: TCI -> 42.61
# Fetched 2777/2892: JYNT -> 11.54
# Fetched 2778/2892: TNXP -> 35.98
# Fetched 2779/2892: ESCA -> 13.6769
# Fetched 2780/2892: CMT -> 16.59
# Fetched 2781/2892: KLC -> 10.1
# Fetched 2782/2892: EPSN -> 7.2033
# Fetched 2783/2892: TMCI -> 5.88
# Fetched 2784/2892: SUNS -> 9.9947
# Fetched 2785/2892: ESOA -> 9.844
# Fetched 2786/2892: SGC -> 10.0299
# Fetched 2787/2892: KRO -> 6.0783
# Fetched 2788/2892: SATL -> 3.62
# Fetched 2789/2892: HPK -> 9.6919
# Fetched 2790/2892: KULR -> 7.13
# Fetched 2791/2892: GWRS -> 10.0364
# Fetched 2792/2892: HAIN -> 1.52
# Fetched 2793/2892: ADV -> 1.32
# Fetched 2794/2892: OFLX -> 31.6864
# Fetched 2795/2892: DCGO -> 1.57
# Fetched 2796/2892: NPWR -> 2.47
# Fetched 2797/2892: ALMU -> 16.37
# Fetched 2798/2892: LNSR -> 13.17
# Fetched 2799/2892: EWCZ -> 5.63
# Fetched 2800/2892: AOUT -> 10.45
# Fetched 2801/2892: ALTG -> 6.32
# Fetched 2802/2892: GAMB -> 11.89
# Fetched 2803/2892: EVI -> 21.6196
# Fetched 2804/2892: AOMR -> 8.788
# Fetched 2805/2892: MAPS -> 0.896
# Fetched 2806/2892: RELL -> 9.5341
# Fetched 2807/2892: BARK -> 0.88
# Fetched 2808/2892: MED -> 14.05
# Fetched 2809/2892: RCMT -> 23.57
# Fetched 2810/2892: EEX -> 4.8172
# Fetched 2811/2892: EML -> 22.586
# Fetched 2812/2892: RXT -> 1.28
# Fetched 2813/2892: PAMT -> 12.87
# Fetched 2814/2892: AREN -> 6.2
# Fetched 2815/2892: NKTX -> 1.66
# Fetched 2816/2892: MNTK -> 2.22
# Fetched 2817/2892: HFFG -> 3.18
# Fetched 2818/2892: FORR -> 9.9
# Fetched 2819/2892: LFT -> 2.1069
# Fetched 2820/2892: ARQ -> 5.37
# Fetched 2821/2892: ELDN -> 2.71
# Fetched 2822/2892: ALEC -> 1.4
# Fetched 2823/2892: OM -> 19.21
# Fetched 2824/2892: ELA -> 6.12
# Fetched 2825/2892: MLP -> 18.19
# Fetched 2826/2892: MYPS -> 1.31
# Fetched 2827/2892: AEYE -> 11.65
# Fetched 2828/2892: BYND -> 3.49
# Fetched 2829/2892: FNKO -> 4.76
# Fetched 2830/2892: NXDT -> 3.822
# Fetched 2831/2892: ARAY -> 1.37
# Fetched 2832/2892: BTMD -> 4.02
# Fetched 2833/2892: FLWS -> 4.92
# Fetched 2834/2892: AFCG -> 4.3165
# Fetched 2835/2892: WALD -> 2.45
# Fetched 2836/2892: AISP -> 5.89
# Fetched 2837/2892: FFAI -> 1.68
# Fetched 2838/2892: GYRE -> 7.35
# Fetched 2839/2892: GAIA -> 4.39
# Fetched 2840/2892: FSP -> 1.6187
# Fetched 2841/2892: CWEN/A -> None
# Fetched 2842/2892: EXFY -> 2.59
# Fetched 2843/2892: SMTI -> 28.39
# Fetched 2844/2892: ACDC -> 7.76
# Fetched 2845/2892: NODK -> 12.74
# Fetched 2846/2892: CPSS -> 9.83
# Fetched 2847/2892: AIRJ -> 4.63
# Fetched 2848/2892: ILLR -> 0.931
# Fetched 2849/2892: ATYR -> 5.07
# Fetched 2850/2892: AIRS -> 4.83
# Fetched 2851/2892: NMAX -> 15.13
# Fetched 2852/2892: FF -> 3.7551
# Fetched 2853/2892: KG -> 26.52
# Fetched 2854/2892: AIRO -> 24.07
# Fetched 2855/2892: JILL -> 14.4926
# Fetched 2856/2892: VIRC -> 7.9256
# Fetched 2857/2892: AARD -> 13.52
# Fetched 2858/2892: LFVN -> 12.946
# Fetched 2859/2892: ATOM -> 5.04
# Fetched 2860/2892: SNCR -> 6.85
# Fetched 2861/2892: SNBR -> 6.755
# Fetched 2862/2892: GLSI -> 9.07
# Fetched 2863/2892: OPAL -> 2.42
# Fetched 2864/2892: CURV -> 2.95
# Fetched 2865/2892: RNAC -> 10.39
# Fetched 2866/2892: PROP -> 2.995
# Fetched 2867/2892: NRDY -> 1.63
# Fetched 2868/2892: STIM -> 3.49
# Fetched 2869/2892: HURA -> 2.23
# Fetched 2870/2892: TUSK -> 2.8
# Fetched 2871/2892: SSTI -> 13.055
# Fetched 2872/2892: TKNO -> 4.91
# Fetched 2873/2892: LUNG -> 2.59
# Fetched 2874/2892: TSE -> 3.1095
# Fetched 2875/2892: DH -> 3.9
# Fetched 2876/2892: TZOO -> 12.73
# Fetched 2877/2892: SKIL -> 15.97
# Fetched 2878/2892: EP -> 5.28
# Fetched 2879/2892: LAZR -> 2.87
# Fetched 2880/2892: SLSN -> 4.36
# Fetched 2881/2892: ISPR -> 2.56
# Fetched 2882/2892: INMB -> 2.31
# Fetched 2883/2892: KRRO -> 12.49
# Fetched 2884/2892: TEAD -> 2.48
# Fetched 2885/2892: SEAT -> 33.8
# Fetched 2886/2892: PNRG -> 146.38
# Fetched 2887/2892: NEON -> 25.5
# Fetched 2888/2892: TVRD -> 23.33
# Fetched 2889/2892: RCEL -> 5.29
# Fetched 2890/2892: GOCO -> 5.55
# Fetched 2891/2892: THRD -> 5.43
# Fetched 2892/2892: SBT -> None
# Date 2025-06-30: Attempted: 2892, Succeeded: 2881, Success Rate: 99.62%
#
# Statistics per date:
#           date  attempted  succeeded  success_rate
# 0   2019-12-31       2892       2349      0.812241
# 1   2020-03-31       2892       2362      0.816736
# 2   2020-06-30       2892       2386      0.825035
# 3   2020-09-30       2892       2435      0.841978
# 4   2020-12-31       2892       2502      0.865145
# 5   2021-03-31       2892       2549      0.881397
# 6   2021-06-30       2892       2616      0.904564
# 7   2021-09-30       2892       2090      0.722683
# 8   2021-12-31       2892          0      0.000000
# 9   2022-03-31       2892          0      0.000000
# 10  2022-06-30       2892          0      0.000000
# 11  2022-09-30       2892        795      0.274896
# 12  2023-01-03       2892       2752      0.951591
# 13  2023-03-31       2892       2765      0.956086
# 14  2023-06-30       2892       2777      0.960235
# 15  2023-10-02       2892       2787      0.963693
# 16  2024-01-02       2892       2796      0.966805
# 17  2024-04-01       2892       2809      0.971300
# 18  2024-07-01       2892       2827      0.977524
# 19  2024-09-30       2892       2840      0.982019
# 20  2024-12-31       2892       2851      0.985823
# 21  2025-03-31       2892       2867      0.991355
# 22  2025-06-30       2892       2881      0.996196
